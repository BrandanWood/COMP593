# %% [markdown]
# <a href="https://colab.research.google.com/github/BrandanWood/COMP593/blob/Lab-3/Copy_of_WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
# REMOVED THIS SCRIPT BECAUSE IT IS NO LONGER NEEDED TO RUN LAB SCRIPT

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-13.0.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 3.2 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-13.0.0

# %%
from faker import Faker

fake = Faker()

x = 2
y = "bob"

s = "{} is {}".format(x,y)
print(s)

for _ in range(10):
  print('{} is a {}'.format( fake.name(), fake.job() ) )
# Out:
# 2 is bob
# Julian Burns is a Print production planner
# Anthony Hernandez is a Scientist, water quality
# Lisa Thompson is a Equality and diversity officer
# Hannah Robles is a Legal secretary
# Jason Roach is a Graphic designer
# Karen Thomas is a Embryologist, clinical
# Lisa Daniels is a Engineer, mining
# Kelly Avery is a Advertising account planner
# Roberto Smith is a Manufacturing engineer
# Julia Johnson is a Animator

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
import pprint
from faker import Faker
from datetime import datetime
from random import randint

# Connecting to the DB
conn = sqlite3.connect('social_network.db', timeout=0)

# cursor with Query
c = conn.cursor()
addPersonQuery = """INSERT INTO people (
                      name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

fake = Faker()
# list of provinces and x rand value based on list len - 1
randProvince = ("Alberta", "British Columbia", "Manitoba", "New Brunswick", "Newfoundland and Labrador",
                "Northwest Territories", "Nova Scotia", "Nunavut", "Ontario", "Prince Edward Island",
                "Quebec", "Saskatchewan", "Yukon")



# testing random provinces


# for loop that contains the stuff for fake generation of people
for stuff in range(1000):
  x = randint(0, len(randProvince) - 1)
  print(randProvince[x])
  myPerson = (
              fake.name(),
              fake.ascii_free_email(),
              fake.street_address(),
              fake.city(),
              randProvince[x],
              fake.country(),
              fake.phone_number(),
              fake.sentence(nb_words=10),
              fake.date_of_birth(),
              fake.random_int(min=999, max=2500),
              datetime.now(),
              datetime.now(),
              fake.ipv4_public()
  )
  c.execute(addPersonQuery, myPerson)
  print(myPerson)

# commits the changes to the DB file
conn.commit()




conn.close()
# Out:
# Yukon
# ('Patrick Barber', 'jamesfreeman@hotmail.com', '749 Richard Wells', 'Sandraborough', 'Yukon', 'Macao', '426.408.8018x77581', 'Institution practice specific price last oil capital finish.', datetime.date(1983, 3, 26), 2070, datetime.datetime(2022, 2, 17, 19, 49, 33, 586455), datetime.datetime(2022, 2, 17, 19, 49, 33, 586457), '109.59.66.180')
# Newfoundland and Labrador
# ('Alex Mcpherson', 'john77@yahoo.com', '18222 Andrew Rue Suite 165', 'Reginaland', 'Newfoundland and Labrador', 'Bermuda', '001-400-924-7076x3212', 'Successful size budget sea arrive gun challenge eight.', datetime.date(1984, 12, 26), 1207, datetime.datetime(2022, 2, 17, 19, 49, 33, 592623), datetime.datetime(2022, 2, 17, 19, 49, 33, 592625), '207.22.208.114')
# Yukon
# ('John Morris', 'butlerjames@yahoo.com', '6804 Morgan Row Suite 210', 'Lake Sarah', 'Yukon', 'Svalbard & Jan Mayen Islands', '001-338-721-0109x260', 'Maintain site again company media none human take trip old chance suddenly.', datetime.date(1953, 2, 21), 2115, datetime.datetime(2022, 2, 17, 19, 49, 33, 605465), datetime.datetime(2022, 2, 17, 19, 49, 33, 605466), '208.27.198.68')
# Saskatchewan
# ('Taylor Chambers', 'anneharmon@gmail.com', '37111 Black Brooks', 'Morenoport', 'Saskatchewan', 'New Caledonia', '001-951-381-7579x11783', 'Society particular government any my civil huge surface among sea assume show.', datetime.date(1945, 9, 11), 1593, datetime.datetime(2022, 2, 17, 19, 49, 33, 606982), datetime.datetime(2022, 2, 17, 19, 49, 33, 606984), '215.175.72.94')
# Alberta
# ('Kimberly Zuniga', 'mconrad@gmail.com', '6118 Michael Junction', 'New Erinshire', 'Alberta', 'Benin', '(528)761-9738x3756', 'Area defense prove officer future response.', datetime.date(1995, 4, 25), 1844, datetime.datetime(2022, 2, 17, 19, 49, 33, 608318), datetime.datetime(2022, 2, 17, 19, 49, 33, 608319), '212.241.68.104')
# Newfoundland and Labrador
# ('Kathleen Lara DDS', 'rmartin@gmail.com', '9807 Harold Pine Suite 021', 'Maryfort', 'Newfoundland and Labrador', 'Congo', '248-839-1525x84020', 'Season doctor color sing director of policy foreign kid concern.', datetime.date(1949, 11, 16), 1906, datetime.datetime(2022, 2, 17, 19, 49, 33, 609600), datetime.datetime(2022, 2, 17, 19, 49, 33, 609601), '207.96.126.251')
# New Brunswick
# ('David Fisher DDS', 'ebell@gmail.com', '15421 Victor Trace', 'Walkerbury', 'New Brunswick', 'Armenia', '+1-988-382-3756', 'Rise outside enough want want anyone bring stop strategy.', datetime.date(1982, 9, 30), 1748, datetime.datetime(2022, 2, 17, 19, 49, 33, 610894), datetime.datetime(2022, 2, 17, 19, 49, 33, 610895), '166.148.148.35')
# Ontario
# ('Jeff Davis', 'nicholas39@yahoo.com', '0078 Chelsea Squares Suite 550', 'Davidmouth', 'Ontario', 'Malawi', '(524)452-6609x58497', 'Past foreign student million into fear seven nothing debate close PM brother.', datetime.date(1982, 8, 13), 1415, datetime.datetime(2022, 2, 17, 19, 49, 33, 615490), datetime.datetime(2022, 2, 17, 19, 49, 33, 615491), '185.80.80.18')
# New Brunswick
# ('Jodi Holder', 'timothyfisher@hotmail.com', '53414 James Cape', 'Annaport', 'New Brunswick', 'Malaysia', '(516)711-5986', 'Seat do will listen north daughter line.', datetime.date(1952, 7, 2), 2250, datetime.datetime(2022, 2, 17, 19, 49, 33, 616824), datetime.datetime(2022, 2, 17, 19, 49, 33, 616825), '3.188.195.194')
# Manitoba
# ('Glenn White', 'ojames@yahoo.com', '6049 Peterson Manors', 'North Hunter', 'Manitoba', 'Bhutan', '455.493.6694', 'Indicate seat brother into director positive reduce guy.', datetime.date(1994, 5, 15), 1180, datetime.datetime(2022, 2, 17, 19, 49, 33, 618085), datetime.datetime(2022, 2, 17, 19, 49, 33, 618087), '152.192.168.240')
# New Brunswick
# ('Bryan Chan', 'wsimpson@gmail.com', '0589 George Walk Suite 110', 'Kathleenside', 'New Brunswick', 'Angola', '001-232-811-9877x36482', 'Talk message to country occur partner.', datetime.date(1982, 11, 12), 2373, datetime.datetime(2022, 2, 17, 19, 49, 33, 619275), datetime.datetime(2022, 2, 17, 19, 49, 33, 619276), '196.61.65.216')
# British Columbia
# ('Lisa Martin', 'lmendez@yahoo.com', '809 Cunningham Station Apt. 522', 'New Samantha', 'British Columbia', 'Sao Tome and Principe', '140.676.4696', 'By mean stay project two want number these call condition might send.', datetime.date(1929, 4, 16), 1842, datetime.datetime(2022, 2, 17, 19, 49, 33, 620511), datetime.datetime(2022, 2, 17, 19, 49, 33, 620512), '215.227.144.7')
# Newfoundland and Labrador
# ('Laura Galloway', 'peterpeterson@yahoo.com', '75574 Jose Shoals', 'Charlesfort', 'Newfoundland and Labrador', 'Romania', '(195)915-8063x667', 'Prevent American game respond morning southern reason TV network hot together same.', datetime.date(1940, 9, 17), 1246, datetime.datetime(2022, 2, 17, 19, 49, 33, 621807), datetime.datetime(2022, 2, 17, 19, 49, 33, 621808), '137.132.55.159')
# Manitoba
# ('Bryan Sloan', 'thomasmorgan@hotmail.com', '7928 Jackson Ramp', 'West Josephland', 'Manitoba', 'French Polynesia', '(336)564-4888x790', 'We show field why from worker program summer difficult.', datetime.date(1919, 6, 26), 1143, datetime.datetime(2022, 2, 17, 19, 49, 33, 623058), datetime.datetime(2022, 2, 17, 19, 49, 33, 623060), '43.237.146.33')
# Prince Edward Island
# ('Brandon Cruz', 'jeffreyrodriguez@hotmail.com', '9940 Candice Land Suite 076', 'West Johnnybury', 'Prince Edward Island', 'Dominican Republic', '+1-816-692-5095x16468', 'Would fast rate agreement between treatment.', datetime.date(2002, 1, 2), 2459, datetime.datetime(2022, 2, 17, 19, 49, 33, 624297), datetime.datetime(2022, 2, 17, 19, 49, 33, 624298), '215.168.248.194')
# Alberta
# ('Carolyn Guzman', 'qsalas@hotmail.com', '53801 Lee Springs', 'Port Moniquefurt', 'Alberta', 'Bermuda', '809.686.0121', 'Game scene sure do door pay south.', datetime.date(1962, 3, 11), 1777, datetime.datetime(2022, 2, 17, 19, 49, 33, 625514), datetime.datetime(2022, 2, 17, 19, 49, 33, 625515), '56.59.89.229')
# Saskatchewan
# ('Juan Goodwin', 'kwright@gmail.com', '5267 Willis Expressway Suite 266', 'Port Robert', 'Saskatchewan', 'Pitcairn Islands', '001-284-058-0323x20458', 'Couple sing table design writer writer well.', datetime.date(1906, 4, 28), 2046, datetime.datetime(2022, 2, 17, 19, 49, 33, 626785), datetime.datetime(2022, 2, 17, 19, 49, 33, 626786), '194.34.153.44')
# Ontario
# ('Sara Jimenez', 'gordonnicole@yahoo.com', '690 Kristin Corner Apt. 754', 'New Jessicatown', 'Ontario', 'Argentina', '+1-800-759-1085x52961', 'With whole person yes citizen way eight year thank police edge cup exactly.', datetime.date(1910, 10, 1), 1036, datetime.datetime(2022, 2, 17, 19, 49, 33, 627849), datetime.datetime(2022, 2, 17, 19, 49, 33, 627850), '221.36.29.56')
# Prince Edward Island
# ('Douglas Patton', 'markwu@gmail.com', '1070 John Crossroad', 'Port Terranceland', 'Prince Edward Island', 'French Guiana', '072.930.1768', 'Director young ten alone she growth middle question add throw rule.', datetime.date(1911, 8, 15), 1662, datetime.datetime(2022, 2, 17, 19, 49, 33, 628762), datetime.datetime(2022, 2, 17, 19, 49, 33, 628763), '217.220.90.84')
# Quebec
# ('Chelsea Rivera', 'rarellano@gmail.com', '61023 Kenneth Plain Apt. 841', 'Frederickchester', 'Quebec', 'Kuwait', '772.440.4915', 'Its baby teacher there group mind really think.', datetime.date(2007, 4, 20), 1205, datetime.datetime(2022, 2, 17, 19, 49, 33, 631005), datetime.datetime(2022, 2, 17, 19, 49, 33, 631007), '158.22.104.219')
# British Columbia
# ('Tiffany Hamilton', 'vramos@yahoo.com', '74730 Wayne Path Apt. 951', 'Morseburgh', 'British Columbia', 'Malaysia', '(788)019-5766x668', 'Can happy try make either character second just seek well something moment us.', datetime.date(2004, 5, 1), 1886, datetime.datetime(2022, 2, 17, 19, 49, 33, 633164), datetime.datetime(2022, 2, 17, 19, 49, 33, 633165), '155.118.69.176')
# Saskatchewan
# ('Kenneth Miller', 'bryanjohnson@hotmail.com', '2168 King Circle', 'Darrellview', 'Saskatchewan', 'Barbados', '1724284186', 'Home hard try hair company test.', datetime.date(2012, 2, 11), 1670, datetime.datetime(2022, 2, 17, 19, 49, 33, 634732), datetime.datetime(2022, 2, 17, 19, 49, 33, 634734), '221.204.108.61')
# Alberta
# ('Mrs. Carolyn Harper', 'suzanneschaefer@hotmail.com', '81732 Brian Turnpike Apt. 150', 'Tristanshire', 'Alberta', 'Aruba', '001-174-837-4725x3829', 'Image out box what manage mission sure.', datetime.date(2009, 5, 28), 1819, datetime.datetime(2022, 2, 17, 19, 49, 33, 636713), datetime.datetime(2022, 2, 17, 19, 49, 33, 636714), '71.220.199.151')
# Manitoba
# ('Jeremy Nguyen', 'anthony38@hotmail.com', '9426 Wilson Ranch', 'Carrillochester', 'Manitoba', 'Djibouti', '+1-233-391-9625', 'About price hour end attack special name long right race.', datetime.date(1988, 12, 30), 2024, datetime.datetime(2022, 2, 17, 19, 49, 33, 638489), datetime.datetime(2022, 2, 17, 19, 49, 33, 638490), '155.221.120.166')
# Ontario
# ('David Jones', 'diazglenn@hotmail.com', '8080 Mooney Crescent', 'Port Mark', 'Ontario', 'Korea', '640-882-3827x633', 'Agent wish stock network administration scene.', datetime.date(1955, 8, 25), 1661, datetime.datetime(2022, 2, 17, 19, 49, 33, 640373), datetime.datetime(2022, 2, 17, 19, 49, 33, 640374), '213.98.245.239')
# Prince Edward Island
# ('Mr. Clayton Gomez', 'susancox@hotmail.com', '1957 Benjamin Way', 'West William', 'Prince Edward Island', 'Botswana', '001-291-460-9478x9614', 'Very police family game book follow federal color pretty task available hit pay.', datetime.date(1984, 8, 15), 2090, datetime.datetime(2022, 2, 17, 19, 49, 33, 642222), datetime.datetime(2022, 2, 17, 19, 49, 33, 642223), '198.165.111.138')
# Newfoundland and Labrador
# ('Tyler Bishop', 'davisbriana@hotmail.com', '8888 Kenneth Vista Apt. 507', 'Andrewbury', 'Newfoundland and Labrador', 'Svalbard & Jan Mayen Islands', '001-406-535-6216x47146', 'Threat such great against involve section business station town follow together.', datetime.date(1918, 8, 2), 1857, datetime.datetime(2022, 2, 17, 19, 49, 33, 644012), datetime.datetime(2022, 2, 17, 19, 49, 33, 644013), '183.27.234.48')
# New Brunswick
# ('Kim Green', 'zhanson@yahoo.com', '180 Pam Branch Apt. 488', 'Lopezborough', 'New Brunswick', 'Somalia', '117.972.6548', 'Range now owner friend art check mouth determine action street say.', datetime.date(1956, 12, 23), 1035, datetime.datetime(2022, 2, 17, 19, 49, 33, 645803), datetime.datetime(2022, 2, 17, 19, 49, 33, 645804), '186.197.249.184')
# Saskatchewan
# ('Jason Hicks', 'judy91@hotmail.com', '2907 Rick Trace Apt. 304', 'Rachaelside', 'Saskatchewan', 'Bolivia', '479.582.1986x6230', 'Machine necessary service step bill realize worker product another election lay scientist room.', datetime.date(1957, 12, 7), 2004, datetime.datetime(2022, 2, 17, 19, 49, 33, 646844), datetime.datetime(2022, 2, 17, 19, 49, 33, 646845), '91.195.64.66')
# Manitoba
# ('Debra Fernandez', 'benjaminpark@gmail.com', '5000 Ward Villages Apt. 773', 'Howardfurt', 'Manitoba', 'Guam', '029.250.5086', 'Water guy safe small again dream.', datetime.date(1922, 9, 21), 1986, datetime.datetime(2022, 2, 17, 19, 49, 33, 647711), datetime.datetime(2022, 2, 17, 19, 49, 33, 647712), '146.89.95.175')
# Saskatchewan
# ('Richard Carter', 'batesgina@hotmail.com', '987 Henry Island', 'Davidside', 'Saskatchewan', 'Lebanon', '496.330.9183', 'Kid seven nice speak your again grow offer current else.', datetime.date(1948, 6, 29), 2292, datetime.datetime(2022, 2, 17, 19, 49, 33, 648501), datetime.datetime(2022, 2, 17, 19, 49, 33, 648503), '198.123.149.210')
# Alberta
# ('Michael Strickland', 'nwhitehead@hotmail.com', '9922 Noah Cliffs Apt. 644', 'West Edward', 'Alberta', 'Anguilla', '001-333-153-5569x2242', 'Too if admit know boy Mr south reality player.', datetime.date(2016, 2, 1), 1561, datetime.datetime(2022, 2, 17, 19, 49, 33, 649325), datetime.datetime(2022, 2, 17, 19, 49, 33, 649327), '121.209.69.109')
# New Brunswick
# ('Audrey Hansen', 'omorris@hotmail.com', '37731 Christopher Green', 'Collinstown', 'New Brunswick', 'Marshall Islands', '+1-264-252-1534x641', 'Compare voice open hour right admit last customer way.', datetime.date(1978, 11, 7), 2460, datetime.datetime(2022, 2, 17, 19, 49, 33, 650032), datetime.datetime(2022, 2, 17, 19, 49, 33, 650034), '36.92.48.166')
# Newfoundland and Labrador
# ('Danielle Hawkins', 'colemichele@hotmail.com', '49827 Greg Alley Apt. 779', 'Ramireztown', 'Newfoundland and Labrador', 'Kuwait', '+1-481-916-1077', 'Student ball rest degree daughter send family beat theory particularly coach laugh.', datetime.date(2017, 12, 4), 1441, datetime.datetime(2022, 2, 17, 19, 49, 33, 650902), datetime.datetime(2022, 2, 17, 19, 49, 33, 650903), '194.175.207.210')
# Saskatchewan
# ('Melanie Hardy', 'shelleyramirez@hotmail.com', '9065 Morse Branch Suite 053', 'Michaeltown', 'Saskatchewan', 'Israel', '765.180.6021', 'Scientist size summer particular politics your material difficult each.', datetime.date(1939, 10, 11), 2336, datetime.datetime(2022, 2, 17, 19, 49, 33, 655111), datetime.datetime(2022, 2, 17, 19, 49, 33, 655113), '113.115.146.219')
# Alberta
# ('James Harrington', 'bhenderson@hotmail.com', '15618 Rodney Center', 'South Jessica', 'Alberta', 'Maldives', '(408)200-5096', 'Build when similar beat maintain policy impact report fast adult successful.', datetime.date(1956, 8, 7), 1218, datetime.datetime(2022, 2, 17, 19, 49, 33, 659019), datetime.datetime(2022, 2, 17, 19, 49, 33, 659020), '151.181.30.73')
# Nunavut
# ('Edward Watson', 'patricia84@hotmail.com', '682 Lawrence Port Suite 344', 'Mooreview', 'Nunavut', 'Cocos (Keeling) Islands', '(762)533-4303', 'Fund sit last certainly family central exactly development.', datetime.date(1935, 5, 28), 1930, datetime.datetime(2022, 2, 17, 19, 49, 33, 660851), datetime.datetime(2022, 2, 17, 19, 49, 33, 660852), '81.46.10.81')
# Yukon
# ('Katherine Petty', 'michaelwright@hotmail.com', '38776 Grant Cliffs Apt. 935', 'West Sarah', 'Yukon', 'Cameroon', '+1-896-407-0948x9434', 'Politics material open yes population have.', datetime.date(2005, 1, 9), 2288, datetime.datetime(2022, 2, 17, 19, 49, 33, 662710), datetime.datetime(2022, 2, 17, 19, 49, 33, 662712), '223.229.228.42')
# New Brunswick
# ('Philip Stuart', 'bernardmichael@hotmail.com', '104 Amanda Forest Apt. 167', 'Valdeztown', 'New Brunswick', 'Russian Federation', '958.589.0136x3447', 'School shoulder specific star place common can maybe day full close.', datetime.date(1991, 4, 2), 1050, datetime.datetime(2022, 2, 17, 19, 49, 33, 664605), datetime.datetime(2022, 2, 17, 19, 49, 33, 664607), '128.38.218.68')
# Quebec
# ('Michelle Clark', 'daltonbartlett@yahoo.com', '698 Allen Brooks', 'Lake Nicholas', 'Quebec', 'Myanmar', '047.190.8348', 'South defense structure against new organization those note wife.', datetime.date(1951, 1, 15), 1064, datetime.datetime(2022, 2, 17, 19, 49, 33, 666455), datetime.datetime(2022, 2, 17, 19, 49, 33, 666457), '103.234.90.71')
# Ontario
# ('Annette Williams', 'pruittmichael@gmail.com', '14811 April Rest Apt. 227', 'Bryanthaven', 'Ontario', 'Cameroon', '557.245.0621x949', 'Story image need purpose century prove floor difference across apply teacher keep system.', datetime.date(1978, 5, 10), 1748, datetime.datetime(2022, 2, 17, 19, 49, 33, 669572), datetime.datetime(2022, 2, 17, 19, 49, 33, 669574), '200.38.147.96')
# New Brunswick
# ('Jodi Cooper', 'alexander59@yahoo.com', '264 Mccullough Parkways', 'Vaughnton', 'New Brunswick', 'United Arab Emirates', '+1-654-526-4480x2298', 'Last go tend bad hand company here maintain remember bring.', datetime.date(1939, 1, 10), 2288, datetime.datetime(2022, 2, 17, 19, 49, 33, 671030), datetime.datetime(2022, 2, 17, 19, 49, 33, 671032), '190.127.104.242')
# New Brunswick
# ('John Adkins', 'lisa41@hotmail.com', '577 Brown Turnpike Suite 716', 'Boydville', 'New Brunswick', 'Nigeria', '176.362.1400x4157', 'Star identify black guess provide set because.', datetime.date(1942, 5, 24), 1895, datetime.datetime(2022, 2, 17, 19, 49, 33, 673039), datetime.datetime(2022, 2, 17, 19, 49, 33, 673040), '139.198.185.17')
# Quebec
# ('Justin Brown', 'shampton@yahoo.com', '1299 Crystal Grove Suite 732', 'Lake Yvette', 'Quebec', 'Uruguay', '817.723.8706x8544', 'Force debate piece medical loss action magazine.', datetime.date(1981, 5, 18), 1193, datetime.datetime(2022, 2, 17, 19, 49, 33, 674930), datetime.datetime(2022, 2, 17, 19, 49, 33, 674932), '94.249.134.44')
# Alberta
# ('Carla Ruiz', 'ywilliams@yahoo.com', '129 Sharon Fall Apt. 519', 'Timothyfort', 'Alberta', 'New Caledonia', '130-352-5696x789', 'By seven kind often question tend recognize.', datetime.date(1913, 1, 17), 2110, datetime.datetime(2022, 2, 17, 19, 49, 33, 677102), datetime.datetime(2022, 2, 17, 19, 49, 33, 677104), '223.210.92.136')
# Saskatchewan
# ('Melissa Herrera', 'gpearson@yahoo.com', '125 Watkins Roads Apt. 430', 'Longfort', 'Saskatchewan', 'Croatia', '(277)078-4063', 'Ground hospital onto learn than drug doctor you late special return.', datetime.date(1973, 12, 4), 1673, datetime.datetime(2022, 2, 17, 19, 49, 33, 678956), datetime.datetime(2022, 2, 17, 19, 49, 33, 678958), '108.177.15.151')
# Alberta
# ('Wendy Cross', 'kevinwright@hotmail.com', '1320 Charles Locks', 'Port Eugene', 'Alberta', 'Nigeria', '586-940-5065', 'While bag force mean food gun send mission process whom.', datetime.date(1910, 8, 19), 2327, datetime.datetime(2022, 2, 17, 19, 49, 33, 680751), datetime.datetime(2022, 2, 17, 19, 49, 33, 680752), '196.183.67.92')
# Prince Edward Island
# ('James Barrett', 'wcharles@gmail.com', '997 James Harbor Apt. 327', 'North Cherylchester', 'Prince Edward Island', 'Bolivia', '379.677.2666', 'Magazine box Mr economic visit citizen activity.', datetime.date(1940, 8, 18), 1409, datetime.datetime(2022, 2, 17, 19, 49, 33, 682762), datetime.datetime(2022, 2, 17, 19, 49, 33, 682763), '58.72.114.230')
# New Brunswick
# ('Calvin Lewis', 'cenglish@gmail.com', '5470 Sanchez Highway', 'Smithstad', 'New Brunswick', 'Saint Vincent and the Grenadines', '001-245-964-4211x6166', 'Behind star scene PM most less goal view perform bring economy doctor matter art.', datetime.date(1965, 6, 5), 1499, datetime.datetime(2022, 2, 17, 19, 49, 33, 684889), datetime.datetime(2022, 2, 17, 19, 49, 33, 684890), '19.213.97.47')
# Yukon
# ('Brandon Spencer', 'qsawyer@yahoo.com', '9820 Kimberly Brook Apt. 805', 'Michellemouth', 'Yukon', 'Netherlands', '181-461-2040x6793', 'Career happy poor mind response drug ok challenge themselves physical research degree town.', datetime.date(1966, 6, 7), 1992, datetime.datetime(2022, 2, 17, 19, 49, 33, 686619), datetime.datetime(2022, 2, 17, 19, 49, 33, 686620), '112.206.145.133')
# Saskatchewan
# ('Elizabeth Rogers', 'richardhayes@hotmail.com', '607 Freeman Cape Suite 467', 'New Timothyside', 'Saskatchewan', 'Marshall Islands', '093.978.0475', 'Include among age meet beat economic country.', datetime.date(1936, 1, 25), 1893, datetime.datetime(2022, 2, 17, 19, 49, 33, 688402), datetime.datetime(2022, 2, 17, 19, 49, 33, 688403), '192.184.252.189')
# Manitoba
# ('Alan Hogan', 'rachael07@gmail.com', '58903 Buchanan Haven', 'Lake Michaelfort', 'Manitoba', 'Colombia', '(924)680-5133x285', 'Contain stand strong task resource brother number bank fund.', datetime.date(1945, 4, 22), 2282, datetime.datetime(2022, 2, 17, 19, 49, 33, 692588), datetime.datetime(2022, 2, 17, 19, 49, 33, 692590), '161.49.11.160')
# Manitoba
# ('Lisa Gomez', 'monica07@hotmail.com', '34457 Romero Grove Suite 157', 'New Ginafurt', 'Manitoba', 'Guinea', '(051)260-6177', 'Ready may everything toward difficult somebody your expect.', datetime.date(1968, 12, 23), 2081, datetime.datetime(2022, 2, 17, 19, 49, 33, 694788), datetime.datetime(2022, 2, 17, 19, 49, 33, 694790), '213.54.34.30')
# Prince Edward Island
# ('William Gonzales', 'oedwards@yahoo.com', '44512 Kristin Ways', 'Wilsonborough', 'Prince Edward Island', 'Sierra Leone', '001-489-617-8597x118', 'Data look current surface kitchen food month administration cost themselves degree color.', datetime.date(1972, 10, 7), 2492, datetime.datetime(2022, 2, 17, 19, 49, 33, 696665), datetime.datetime(2022, 2, 17, 19, 49, 33, 696667), '121.235.152.137')
# Newfoundland and Labrador
# ('Brian Wang', 'megan32@hotmail.com', '7513 Ryan Pines Suite 734', 'Stevenmouth', 'Newfoundland and Labrador', 'Iran', '263.184.9033', 'Why six network PM recent institution center apply.', datetime.date(2003, 11, 24), 2343, datetime.datetime(2022, 2, 17, 19, 49, 33, 699286), datetime.datetime(2022, 2, 17, 19, 49, 33, 699287), '206.107.23.96')
# Ontario
# ('Miguel Adams', 'uaguilar@yahoo.com', '9862 Cox Pike Apt. 354', 'Saraton', 'Ontario', 'Wallis and Futuna', '+1-796-750-6741x6684', 'Commercial practice school quality subject message.', datetime.date(1912, 7, 15), 1240, datetime.datetime(2022, 2, 17, 19, 49, 33, 700176), datetime.datetime(2022, 2, 17, 19, 49, 33, 700177), '54.194.148.149')
# Nunavut
# ('Karen Prince', 'cory84@yahoo.com', '66005 Susan Common', 'East Angelamouth', 'Nunavut', 'British Virgin Islands', '440.249.8476x1193', 'Car budget account finally either suggest machine see.', datetime.date(2006, 10, 18), 1177, datetime.datetime(2022, 2, 17, 19, 49, 33, 701845), datetime.datetime(2022, 2, 17, 19, 49, 33, 701846), '81.192.3.95')
# Manitoba
# ('Theresa Lowe', 'brianmorris@hotmail.com', '0500 Jennifer Lakes Apt. 982', 'Walkerfort', 'Manitoba', 'Wallis and Futuna', '+1-171-461-3126', 'No agreement one history minute military.', datetime.date(2005, 2, 10), 2212, datetime.datetime(2022, 2, 17, 19, 49, 33, 704449), datetime.datetime(2022, 2, 17, 19, 49, 33, 704450), '169.203.241.158')
# Prince Edward Island
# ('Aaron Bailey', 'rortiz@hotmail.com', '69965 Richmond Parkway', 'New Christopher', 'Prince Edward Island', 'Fiji', '(740)593-4795', 'Very leg theory through send support around item her.', datetime.date(1923, 10, 12), 2319, datetime.datetime(2022, 2, 17, 19, 49, 33, 705668), datetime.datetime(2022, 2, 17, 19, 49, 33, 705669), '183.207.255.143')
# New Brunswick
# ('Susan Martinez', 'matthewlee@gmail.com', '68102 Nicholas Parkway', 'West Thomas', 'New Brunswick', 'Tunisia', '+1-872-467-2843x946', 'Coach into eight summer music reason pretty.', datetime.date(1993, 12, 4), 1917, datetime.datetime(2022, 2, 17, 19, 49, 33, 706592), datetime.datetime(2022, 2, 17, 19, 49, 33, 706594), '56.151.142.74')
# Manitoba
# ('Stephanie Butler', 'megan88@gmail.com', '7121 Emily Trafficway Apt. 971', 'East Danielbury', 'Manitoba', 'South Africa', '097-555-0394x002', 'Difference pretty media born key certain heart six majority great test public purpose.', datetime.date(1942, 5, 25), 1527, datetime.datetime(2022, 2, 17, 19, 49, 33, 709284), datetime.datetime(2022, 2, 17, 19, 49, 33, 709286), '184.116.213.195')
# Manitoba
# ('Sharon Garcia', 'chadrobles@gmail.com', '598 Thomas Lodge Apt. 103', 'Port Jacob', 'Manitoba', 'Seychelles', '312.223.8927', 'Part level color husband next actually statement determine yes.', datetime.date(1949, 1, 6), 1642, datetime.datetime(2022, 2, 17, 19, 49, 33, 711512), datetime.datetime(2022, 2, 17, 19, 49, 33, 711513), '223.160.144.88')
# Ontario
# ('Michael Day', 'nbishop@gmail.com', '1568 Ray Well', 'Jonathantown', 'Ontario', 'New Caledonia', '001-920-917-3359x7603', 'Seem specific national lay politics themselves hair relationship.', datetime.date(1917, 12, 18), 2439, datetime.datetime(2022, 2, 17, 19, 49, 33, 713328), datetime.datetime(2022, 2, 17, 19, 49, 33, 713329), '27.47.140.85')
# Quebec
# ('Daniel Parker', 'jonathan04@gmail.com', '493 Gray Plain Suite 127', 'East Brittanyborough', 'Quebec', 'Georgia', '(715)430-0606x50214', 'With throughout last decide memory you explain film place treatment rule address.', datetime.date(2016, 10, 17), 2490, datetime.datetime(2022, 2, 17, 19, 49, 33, 715057), datetime.datetime(2022, 2, 17, 19, 49, 33, 715058), '162.197.109.210')
# Saskatchewan
# ('Michael Joseph', 'rodgerslisa@gmail.com', '7595 Ramirez Pass Suite 010', 'North Troy', 'Saskatchewan', 'French Southern Territories', '001-472-292-0222', 'Pull after close material role may leave feel claim without always truth girl.', datetime.date(1970, 2, 13), 1404, datetime.datetime(2022, 2, 17, 19, 49, 33, 716010), datetime.datetime(2022, 2, 17, 19, 49, 33, 716012), '202.195.207.165')
# British Columbia
# ('Tristan Ryan', 'heidi15@hotmail.com', '738 Garcia Field', 'Morenoborough', 'British Columbia', 'Belize', '123-952-6107x02001', 'Serve capital particularly last share fill eye pretty kind above.', datetime.date(1938, 10, 5), 1898, datetime.datetime(2022, 2, 17, 19, 49, 33, 718607), datetime.datetime(2022, 2, 17, 19, 49, 33, 718608), '8.206.122.179')
# Northwest Territories
# ('Anthony Peterson', 'syoung@yahoo.com', '21151 Sheila Passage Suite 130', 'New Holly', 'Northwest Territories', 'Indonesia', '001-996-220-0503x00897', 'Lead major color turn season music analysis TV business.', datetime.date(1931, 9, 8), 1681, datetime.datetime(2022, 2, 17, 19, 49, 33, 719857), datetime.datetime(2022, 2, 17, 19, 49, 33, 719858), '223.103.92.123')
# Alberta
# ('Pamela Underwood', 'richard96@yahoo.com', '3502 Miranda Crossing', 'Dwaynetown', 'Alberta', 'Swaziland', '8632993538', 'Report line drop start less always line natural anyone suddenly herself.', datetime.date(1949, 8, 23), 1704, datetime.datetime(2022, 2, 17, 19, 49, 33, 721927), datetime.datetime(2022, 2, 17, 19, 49, 33, 721928), '160.184.253.251')
# Saskatchewan
# ('Katelyn Freeman', 'karlwoodard@hotmail.com', '62166 Taylor Via Apt. 133', 'Clintonfort', 'Saskatchewan', 'France', '+1-547-262-7438x447', 'Trial off clear both office she participant want light effort same guess.', datetime.date(1944, 10, 12), 2407, datetime.datetime(2022, 2, 17, 19, 49, 33, 724326), datetime.datetime(2022, 2, 17, 19, 49, 33, 724328), '213.67.166.139')
# Yukon
# ('Steven Green', 'herrerageorge@gmail.com', '75533 Zimmerman Lane', 'Ethanshire', 'Yukon', 'Denmark', '(728)386-0335', 'Rest I assume ten read leg.', datetime.date(1973, 4, 17), 2166, datetime.datetime(2022, 2, 17, 19, 49, 33, 726216), datetime.datetime(2022, 2, 17, 19, 49, 33, 726218), '85.202.120.201')
# Saskatchewan
# ('Sarah Turner', 'barbaratodd@hotmail.com', '5704 Maria Meadow', 'Lake Melvinbury', 'Saskatchewan', 'Kiribati', '914.328.7067x29028', 'Business teacher various would school suffer travel account who.', datetime.date(1950, 11, 29), 2052, datetime.datetime(2022, 2, 17, 19, 49, 33, 728044), datetime.datetime(2022, 2, 17, 19, 49, 33, 728045), '138.64.100.18')
# Northwest Territories
# ('Ashley Peters', 'tina71@gmail.com', '533 Bradley Freeway Apt. 029', 'Lake Katherineborough', 'Northwest Territories', 'Bulgaria', '+1-714-899-6103x503', 'Explain agree decade back beyond part message smile ground cover lead.', datetime.date(2018, 3, 21), 1183, datetime.datetime(2022, 2, 17, 19, 49, 33, 730620), datetime.datetime(2022, 2, 17, 19, 49, 33, 730621), '142.228.246.118')
# Nova Scotia
# ('Sarah Graham', 'whendrix@gmail.com', '977 Brianna Inlet Suite 667', 'Lake Christophertown', 'Nova Scotia', 'Guatemala', '+1-907-706-5055', 'Sister else scientist move measure its occur.', datetime.date(1962, 8, 8), 1237, datetime.datetime(2022, 2, 17, 19, 49, 33, 731954), datetime.datetime(2022, 2, 17, 19, 49, 33, 731955), '185.129.91.51')
# Northwest Territories
# ('Julie Butler', 'sarahclements@hotmail.com', '24721 Christopher Trace', 'Dannybury', 'Northwest Territories', 'Myanmar', '+1-877-405-0225x290', 'Crime western large care fast paper wrong season need nearly standard could.', datetime.date(1968, 7, 5), 1320, datetime.datetime(2022, 2, 17, 19, 49, 33, 733361), datetime.datetime(2022, 2, 17, 19, 49, 33, 733362), '126.198.135.151')
# Alberta
# ('Amy Barber', 'pearsontroy@yahoo.com', '786 Kristin Club', 'West Daniel', 'Alberta', 'Seychelles', '170.332.4188', 'Machine affect often field discussion national push attention work.', datetime.date(1952, 3, 3), 1635, datetime.datetime(2022, 2, 17, 19, 49, 33, 735123), datetime.datetime(2022, 2, 17, 19, 49, 33, 735124), '39.228.178.173')
# New Brunswick
# ('Jennifer Boyle', 'melissa06@hotmail.com', '903 Donald Squares', 'New Cassandramouth', 'New Brunswick', 'Palestinian Territory', '+1-448-577-4692x230', 'Son break reason rich night training cause back season gas claim skin.', datetime.date(2000, 12, 20), 1218, datetime.datetime(2022, 2, 17, 19, 49, 33, 736773), datetime.datetime(2022, 2, 17, 19, 49, 33, 736775), '141.218.184.191')
# Alberta
# ('William Fisher', 'qadkins@hotmail.com', '342 Christine Mountain Suite 888', 'North Garrettland', 'Alberta', 'Central African Republic', '+1-889-859-8852x972', 'Blue loss see ok while range improve about describe.', datetime.date(1924, 8, 21), 1358, datetime.datetime(2022, 2, 17, 19, 49, 33, 738553), datetime.datetime(2022, 2, 17, 19, 49, 33, 738554), '138.2.146.169')
# British Columbia
# ('Brandon Garrett', 'kbrown@gmail.com', '9133 Hayden Village', 'Hayesville', 'British Columbia', "Lao People's Democratic Republic", '(400)429-9537', 'Lead himself spring piece hospital listen reveal parent this air.', datetime.date(1947, 10, 23), 1899, datetime.datetime(2022, 2, 17, 19, 49, 33, 740284), datetime.datetime(2022, 2, 17, 19, 49, 33, 740285), '158.136.78.116')
# New Brunswick
# ('Annette Ward', 'nicolereed@hotmail.com', '0838 Velasquez Forges', 'Lake Christopher', 'New Brunswick', 'Saint Vincent and the Grenadines', '115-671-5637x273', 'Reveal figure sense central career behavior door far to.', datetime.date(1929, 11, 24), 1411, datetime.datetime(2022, 2, 17, 19, 49, 33, 742814), datetime.datetime(2022, 2, 17, 19, 49, 33, 742815), '207.106.240.59')
# Quebec
# ('Stephen Gutierrez', 'schwartzdaniel@gmail.com', '973 Larry Dam Suite 032', 'Sanchezmouth', 'Quebec', 'Bouvet Island (Bouvetoya)', '(803)662-0435', 'Forget off yard continue between husband hospital record suffer special leg gas open.', datetime.date(1991, 11, 23), 1240, datetime.datetime(2022, 2, 17, 19, 49, 33, 744423), datetime.datetime(2022, 2, 17, 19, 49, 33, 744425), '116.84.28.175')
# Yukon
# ('Paul Andrade', 'lgates@gmail.com', '68401 Ochoa Shore Apt. 481', 'Schultzmouth', 'Yukon', 'Madagascar', '+1-497-180-9870x62869', 'Sometimes view bar home half individual shake must this these plant follow just.', datetime.date(1987, 8, 9), 1155, datetime.datetime(2022, 2, 17, 19, 49, 33, 745553), datetime.datetime(2022, 2, 17, 19, 49, 33, 745554), '175.5.184.12')
# Prince Edward Island
# ('William Aguilar', 'sarahacosta@yahoo.com', '342 Foster Camp Suite 495', 'East John', 'Prince Edward Island', 'Tajikistan', '+1-959-780-5452x37209', 'Stop make season case report cell less figure central eye language raise wish.', datetime.date(1945, 9, 8), 1763, datetime.datetime(2022, 2, 17, 19, 49, 33, 746994), datetime.datetime(2022, 2, 17, 19, 49, 33, 746995), '103.187.47.195')
# Northwest Territories
# ('Elizabeth Welch', 'kentrobert@yahoo.com', '44953 Deborah Knoll Suite 191', 'Shawmouth', 'Northwest Territories', 'Zimbabwe', '+1-951-817-2116x4933', 'Live state gas wife point class four.', datetime.date(1945, 12, 30), 1896, datetime.datetime(2022, 2, 17, 19, 49, 33, 748007), datetime.datetime(2022, 2, 17, 19, 49, 33, 748008), '150.211.151.135')
# Northwest Territories
# ('Phillip Schwartz', 'beverly99@yahoo.com', '17666 Mark Springs Suite 798', 'Collinsfort', 'Northwest Territories', 'Russian Federation', '374-710-2500x88383', 'Report source condition probably result moment whose difference.', datetime.date(1913, 10, 30), 1902, datetime.datetime(2022, 2, 17, 19, 49, 33, 750860), datetime.datetime(2022, 2, 17, 19, 49, 33, 750862), '51.130.249.231')
# Ontario
# ('Joshua Brooks', 'bsummers@gmail.com', '2673 James Island Suite 742', 'West Victorburgh', 'Ontario', 'Indonesia', '(080)176-3366', 'History again myself hold age eat treat.', datetime.date(1906, 7, 11), 2054, datetime.datetime(2022, 2, 17, 19, 49, 33, 752879), datetime.datetime(2022, 2, 17, 19, 49, 33, 752880), '128.150.6.170')
# Yukon
# ('Dennis Mack', 'dyoung@hotmail.com', '6367 Mendoza Ridge Suite 993', 'West Kimberlyhaven', 'Yukon', 'Dominica', '452.519.3110x921', 'Study arrive gas vote natural thank step.', datetime.date(1913, 8, 31), 1247, datetime.datetime(2022, 2, 17, 19, 49, 33, 754685), datetime.datetime(2022, 2, 17, 19, 49, 33, 754687), '160.130.2.29')
# Newfoundland and Labrador
# ('Catherine Perez', 'evansjessica@gmail.com', '320 Todd Forges', 'Duncanchester', 'Newfoundland and Labrador', 'Guyana', '704.641.7178x07213', 'Serious decade everybody nothing forward cost.', datetime.date(1985, 6, 9), 1570, datetime.datetime(2022, 2, 17, 19, 49, 33, 756452), datetime.datetime(2022, 2, 17, 19, 49, 33, 756454), '111.121.123.242')
# Manitoba
# ('Michael Miller', 'sarahgonzalez@gmail.com', '2870 Randall Square', 'Danielschester', 'Manitoba', 'Pakistan', '(591)105-2095', 'Issue before several happen forward executive best miss better kid usually quite.', datetime.date(1963, 7, 7), 1790, datetime.datetime(2022, 2, 17, 19, 49, 33, 758225), datetime.datetime(2022, 2, 17, 19, 49, 33, 758226), '132.20.202.226')
# Ontario
# ('Jessica Miller', 'michaelevans@gmail.com', '07466 Frazier Tunnel Suite 528', 'West Matthew', 'Ontario', 'Guadeloupe', '539-669-4563x878', 'Sense leader three full section cut begin loss mind media beat total describe.', datetime.date(1936, 7, 21), 2022, datetime.datetime(2022, 2, 17, 19, 49, 33, 759953), datetime.datetime(2022, 2, 17, 19, 49, 33, 759954), '139.163.43.237')
# Manitoba
# ('Patricia Flores', 'bakerpamela@yahoo.com', '914 Pineda Drive', 'Richardsonbury', 'Manitoba', 'Rwanda', '718-756-1102', 'Cup part assume form city wonder audience learn describe hotel sit.', datetime.date(1986, 12, 9), 2258, datetime.datetime(2022, 2, 17, 19, 49, 33, 761696), datetime.datetime(2022, 2, 17, 19, 49, 33, 761697), '15.189.235.11')
# New Brunswick
# ('Isaac Chaney', 'sergioclark@gmail.com', '27767 Hayes Ways Suite 306', 'South Tracytown', 'New Brunswick', 'Bangladesh', '108-105-0995x374', 'Since behind pick collection how pass white always take.', datetime.date(2005, 11, 26), 2343, datetime.datetime(2022, 2, 17, 19, 49, 33, 763446), datetime.datetime(2022, 2, 17, 19, 49, 33, 763448), '211.141.220.141')
# Saskatchewan
# ('Brian Black', 'vasquezlaurie@gmail.com', '49649 Kelly Way Apt. 879', 'South Courtney', 'Saskatchewan', 'Ghana', '+1-462-212-6291', 'Stuff beautiful them short five fear them change.', datetime.date(1987, 9, 1), 2268, datetime.datetime(2022, 2, 17, 19, 49, 33, 765234), datetime.datetime(2022, 2, 17, 19, 49, 33, 765236), '199.224.62.158')
# Quebec
# ('Alex Williams', 'amy13@gmail.com', '024 Garcia Mills Apt. 178', 'West Patrick', 'Quebec', "Lao People's Democratic Republic", '(934)713-0289x732', 'Cover three tell college kid official term security clear resource.', datetime.date(1932, 5, 1), 1246, datetime.datetime(2022, 2, 17, 19, 49, 33, 766906), datetime.datetime(2022, 2, 17, 19, 49, 33, 766907), '218.70.183.151')
# Manitoba
# ('Bonnie Pierce', 'dmartin@hotmail.com', '03169 Pittman Light Apt. 616', 'Lake Nicolemouth', 'Manitoba', 'Switzerland', '001-236-739-1249', 'For agree follow believe another memory early door fact baby coach task before.', datetime.date(1976, 7, 4), 1122, datetime.datetime(2022, 2, 17, 19, 49, 33, 768634), datetime.datetime(2022, 2, 17, 19, 49, 33, 768636), '220.186.131.95')
# Manitoba
# ('Robert Stewart', 'angela72@gmail.com', '050 Johnson Vista', 'Shawnport', 'Manitoba', 'Portugal', '001-336-385-8371x624', 'Minute family summer investment once state first.', datetime.date(2016, 9, 22), 1481, datetime.datetime(2022, 2, 17, 19, 49, 33, 770382), datetime.datetime(2022, 2, 17, 19, 49, 33, 770383), '215.83.111.101')
# Alberta
# ('Carol Stephenson', 'chapmandanielle@yahoo.com', '024 Peck Village Suite 150', 'West Arthurfurt', 'Alberta', 'Tunisia', '082-862-6705', 'Direction goal public consumer enjoy certain oil we page deal.', datetime.date(1945, 8, 31), 2008, datetime.datetime(2022, 2, 17, 19, 49, 33, 772264), datetime.datetime(2022, 2, 17, 19, 49, 33, 772266), '172.191.7.115')
# Northwest Territories
# ('Toni Bowers', 'nhall@hotmail.com', '978 Jonathan Isle Apt. 579', 'Thompsonfort', 'Northwest Territories', 'New Zealand', '+1-583-383-5446x89160', 'Place either travel manager any west high.', datetime.date(1909, 1, 20), 2331, datetime.datetime(2022, 2, 17, 19, 49, 33, 773981), datetime.datetime(2022, 2, 17, 19, 49, 33, 773982), '206.180.197.55')
# Yukon
# ('Joseph Wright', 'graydonna@hotmail.com', '843 Rios Street Apt. 968', 'Benjaminfort', 'Yukon', 'Croatia', '186-995-2816', 'Win American evening nature significant common political.', datetime.date(2013, 11, 20), 1074, datetime.datetime(2022, 2, 17, 19, 49, 33, 775798), datetime.datetime(2022, 2, 17, 19, 49, 33, 775799), '152.228.220.86')
# Alberta
# ('Paige Barrett', 'brooksterri@yahoo.com', '25117 Katie Ferry', 'Lake Benjaminport', 'Alberta', 'Iran', '883-578-6092', 'Possible week participant coach book company.', datetime.date(2021, 2, 15), 2494, datetime.datetime(2022, 2, 17, 19, 49, 33, 777531), datetime.datetime(2022, 2, 17, 19, 49, 33, 777532), '124.151.109.172')
# Yukon
# ('Gary Miles', 'rleonard@yahoo.com', '3351 Mary Cape Apt. 504', 'Spenceview', 'Yukon', 'Armenia', '554.541.4915x277', 'Think billion anyone interest goal a minute letter difference parent.', datetime.date(1983, 1, 19), 1716, datetime.datetime(2022, 2, 17, 19, 49, 33, 779255), datetime.datetime(2022, 2, 17, 19, 49, 33, 779256), '136.146.155.180')
# Yukon
# ('Randy Lambert', 'sydney91@gmail.com', '084 Wallace Ford', 'Lake Alantown', 'Yukon', 'Uzbekistan', '+1-975-449-9820x3746', 'Never bed at now professional while.', datetime.date(1966, 12, 21), 1340, datetime.datetime(2022, 2, 17, 19, 49, 33, 780905), datetime.datetime(2022, 2, 17, 19, 49, 33, 780906), '43.166.111.141')
# Nunavut
# ('Patrick Rodriguez', 'armstrongthomas@hotmail.com', '041 Joseph Plains Suite 042', 'Fowlerstad', 'Nunavut', 'United Kingdom', '(102)217-0599x489', 'Foot again public large brother receive indeed I drive do him type.', datetime.date(2000, 5, 11), 1371, datetime.datetime(2022, 2, 17, 19, 49, 33, 782637), datetime.datetime(2022, 2, 17, 19, 49, 33, 782638), '94.75.31.68')
# Quebec
# ('David Gonzalez', 'donaldhall@hotmail.com', '4067 Romero Plain', 'Georgeton', 'Quebec', 'Niger', '001-462-020-2977', 'Center ten fine wall tend season choice performance foreign here explain.', datetime.date(1948, 10, 28), 1996, datetime.datetime(2022, 2, 17, 19, 49, 33, 784384), datetime.datetime(2022, 2, 17, 19, 49, 33, 784385), '195.170.50.152')
# Ontario
# ('Deborah Ross DDS', 'smithkimberly@gmail.com', '07258 Cindy Lodge Suite 821', 'West Tamara', 'Ontario', 'Singapore', '427-096-5727x631', 'Behind my two wonder available step parent significant page than.', datetime.date(1971, 12, 12), 1395, datetime.datetime(2022, 2, 17, 19, 49, 33, 786157), datetime.datetime(2022, 2, 17, 19, 49, 33, 786158), '165.204.59.211')
# Saskatchewan
# ('Tina Cabrera', 'loganaaron@yahoo.com', '887 Stone Radial', 'Sharonfort', 'Saskatchewan', 'Morocco', '730.305.8147', 'Interest few newspaper score lawyer beat.', datetime.date(1913, 5, 30), 2128, datetime.datetime(2022, 2, 17, 19, 49, 33, 796264), datetime.datetime(2022, 2, 17, 19, 49, 33, 796267), '34.64.159.61')
# Nova Scotia
# ('Chris Guerra', 'madison60@yahoo.com', '48348 Page Loop Suite 075', 'West Richard', 'Nova Scotia', 'Lithuania', '327.179.8016', 'Financial job of class social close table.', datetime.date(1930, 3, 4), 1040, datetime.datetime(2022, 2, 17, 19, 49, 33, 798050), datetime.datetime(2022, 2, 17, 19, 49, 33, 798051), '35.99.241.34')
# Prince Edward Island
# ('Christine Guerrero', 'ghenry@gmail.com', '316 Sutton Track', 'Denisefort', 'Prince Edward Island', 'Germany', '(223)593-8741x8625', 'Learn scientist create somebody word fish rest clear arm whether wind whom on.', datetime.date(1952, 12, 7), 1983, datetime.datetime(2022, 2, 17, 19, 49, 33, 799871), datetime.datetime(2022, 2, 17, 19, 49, 33, 799872), '201.73.205.24')
# Alberta
# ('Crystal Newman', 'lance85@gmail.com', '27056 Susan Road', 'Tonyshire', 'Alberta', 'Saudi Arabia', '457.197.0219x475', 'Fish line opportunity possible group relate truth.', datetime.date(2021, 6, 19), 1579, datetime.datetime(2022, 2, 17, 19, 49, 33, 801622), datetime.datetime(2022, 2, 17, 19, 49, 33, 801623), '128.53.98.246')
# Newfoundland and Labrador
# ('Phillip Dunn', 'uterry@gmail.com', '83646 Ashley Lodge Apt. 615', 'New Carlosfurt', 'Newfoundland and Labrador', 'Antigua and Barbuda', '483.380.8298x88598', 'Ago process sort meeting they black ground return save truth energy throw southern.', datetime.date(1914, 11, 18), 2133, datetime.datetime(2022, 2, 17, 19, 49, 33, 803364), datetime.datetime(2022, 2, 17, 19, 49, 33, 803366), '223.211.203.190')
# New Brunswick
# ('Angela Harris', 'matthew05@hotmail.com', '22121 Garrett Mountain Apt. 397', 'Williambury', 'New Brunswick', 'Eritrea', '577.069.2340x5619', 'Realize hit power area line answer effect service really water hotel order.', datetime.date(1988, 5, 21), 2172, datetime.datetime(2022, 2, 17, 19, 49, 33, 805048), datetime.datetime(2022, 2, 17, 19, 49, 33, 805050), '31.213.254.164')
# Newfoundland and Labrador
# ('Patrick King', 'iallen@yahoo.com', '298 Duarte Shore Suite 056', 'South Davidmouth', 'Newfoundland and Labrador', 'Hong Kong', '+1-585-946-4423x37100', 'The soon fish run purpose cut serve several million research.', datetime.date(1933, 10, 29), 2057, datetime.datetime(2022, 2, 17, 19, 49, 33, 806767), datetime.datetime(2022, 2, 17, 19, 49, 33, 806769), '156.145.163.159')
# Ontario
# ('Stephanie Powell', 'nancyarellano@hotmail.com', '4559 Martinez Mission', 'West Daniel', 'Ontario', 'Nigeria', '635-108-0529x550', 'Be break whom fact after story glass natural site trouble consumer condition unit.', datetime.date(1960, 5, 10), 1346, datetime.datetime(2022, 2, 17, 19, 49, 33, 808545), datetime.datetime(2022, 2, 17, 19, 49, 33, 808546), '159.114.195.187')
# Quebec
# ('Edwin Lewis', 'daniel09@hotmail.com', '77733 Ashley Flat', 'Osbornhaven', 'Quebec', 'Venezuela', '+1-067-420-9310x161', 'Most talk personal why character medical.', datetime.date(2014, 2, 28), 2175, datetime.datetime(2022, 2, 17, 19, 49, 33, 809363), datetime.datetime(2022, 2, 17, 19, 49, 33, 809364), '38.191.150.212')
# British Columbia
# ('Tiffany Lynn', 'hjohnson@yahoo.com', '79452 Collins Locks Apt. 793', 'Lake Zachary', 'British Columbia', 'Uganda', '+1-194-454-3664x99471', 'Song reflect executive rich Republican bad whole born resource.', datetime.date(2007, 9, 2), 1965, datetime.datetime(2022, 2, 17, 19, 49, 33, 811799), datetime.datetime(2022, 2, 17, 19, 49, 33, 811800), '39.14.97.198')
# Yukon
# ('Joshua Scott', 'khurst@hotmail.com', '66303 Ballard Estates Suite 091', 'East Madison', 'Yukon', 'Angola', '001-597-329-3311', 'Soon person animal hour group decade benefit budget son.', datetime.date(1973, 12, 29), 1585, datetime.datetime(2022, 2, 17, 19, 49, 33, 813240), datetime.datetime(2022, 2, 17, 19, 49, 33, 813241), '177.93.28.227')
# British Columbia
# ('Carlos Johnston', 'portega@yahoo.com', '447 Stephanie Lakes', 'Port Julie', 'British Columbia', 'Denmark', '(399)175-5340', 'Speak something they ball born work not artist operation.', datetime.date(1997, 12, 24), 2284, datetime.datetime(2022, 2, 17, 19, 49, 33, 815308), datetime.datetime(2022, 2, 17, 19, 49, 33, 815309), '174.41.23.138')
# Yukon
# ('Jasmine Carroll', 'hancocknicole@yahoo.com', '8199 Kelly Glens Suite 017', 'South Michaelside', 'Yukon', 'Venezuela', '413-700-9039', 'Discussion out it upon which next actually.', datetime.date(1972, 12, 13), 1413, datetime.datetime(2022, 2, 17, 19, 49, 33, 817028), datetime.datetime(2022, 2, 17, 19, 49, 33, 817029), '213.106.117.113')
# Ontario
# ('Sierra Hardin', 'williamspedro@hotmail.com', '8025 Ramos Mission Apt. 316', 'Lake Diamond', 'Ontario', 'Niger', '063-397-4106', 'Ability hot different thing week each commercial.', datetime.date(1944, 12, 1), 1562, datetime.datetime(2022, 2, 17, 19, 49, 33, 818851), datetime.datetime(2022, 2, 17, 19, 49, 33, 818852), '134.176.152.147')
# British Columbia
# ('Joshua Roberts', 'mcdonaldthomas@yahoo.com', '73518 Johnson Drives', 'Port Lynn', 'British Columbia', 'Gibraltar', '(999)610-3786x5013', 'Quality hospital truth professor writer election.', datetime.date(1969, 10, 9), 2454, datetime.datetime(2022, 2, 17, 19, 49, 33, 820601), datetime.datetime(2022, 2, 17, 19, 49, 33, 820602), '192.21.249.45')
# Quebec
# ('Michelle Duncan', 'ojames@yahoo.com', '166 Alexis Ridge', 'Lake Joshuamouth', 'Quebec', 'Mozambique', '+1-270-650-0187x3513', 'Rise determine social film theory kitchen understand doctor wear.', datetime.date(1913, 12, 9), 1294, datetime.datetime(2022, 2, 17, 19, 49, 33, 822329), datetime.datetime(2022, 2, 17, 19, 49, 33, 822330), '20.106.135.236')
# Prince Edward Island
# ('Ruth Davis', 'jthompson@yahoo.com', '282 Olson Overpass', 'Aprilland', 'Prince Edward Island', 'Myanmar', '+1-969-965-5924x427', 'Great better kid both the store there.', datetime.date(2004, 11, 5), 2375, datetime.datetime(2022, 2, 17, 19, 49, 33, 824008), datetime.datetime(2022, 2, 17, 19, 49, 33, 824009), '186.29.146.180')
# Manitoba
# ('Caleb Powell', 'judy20@gmail.com', '6866 Peters Lake', 'Johnnyberg', 'Manitoba', 'Saudi Arabia', '364-854-2482', 'Lose defense citizen role newspaper only.', datetime.date(2015, 3, 11), 2397, datetime.datetime(2022, 2, 17, 19, 49, 33, 825685), datetime.datetime(2022, 2, 17, 19, 49, 33, 825686), '1.139.65.15')
# Saskatchewan
# ('Robert Herrera Jr.', 'vware@yahoo.com', '307 Lowe Knolls', 'Natalieshire', 'Saskatchewan', 'Congo', '001-106-437-9763x208', 'Culture speak financial house director add trial would stop stay democratic story.', datetime.date(1936, 1, 16), 1316, datetime.datetime(2022, 2, 17, 19, 49, 33, 827381), datetime.datetime(2022, 2, 17, 19, 49, 33, 827382), '219.199.200.33')
# Yukon
# ('Debbie Perez', 'hmcclure@gmail.com', '812 Kara Corner Suite 587', 'Derrickmouth', 'Yukon', 'Tunisia', '932.464.8400', 'Against true prove appear somebody feel current.', datetime.date(1938, 12, 26), 1268, datetime.datetime(2022, 2, 17, 19, 49, 33, 829110), datetime.datetime(2022, 2, 17, 19, 49, 33, 829111), '174.79.189.252')
# Newfoundland and Labrador
# ('Jaime Smith', 'jacquelinerogers@gmail.com', '268 Carolyn Prairie Apt. 501', 'Mccoyshire', 'Newfoundland and Labrador', 'Saint Pierre and Miquelon', '(164)760-1301', 'Then finish at father read state area time not season.', datetime.date(1950, 10, 12), 2467, datetime.datetime(2022, 2, 17, 19, 49, 33, 831248), datetime.datetime(2022, 2, 17, 19, 49, 33, 831251), '205.67.86.168')
# New Brunswick
# ('Omar Pollard', 'tfoster@yahoo.com', '17789 Michael Radial', 'Hodgeburgh', 'New Brunswick', 'Estonia', '+1-495-663-5405x796', 'Story knowledge increase production mother tree fly.', datetime.date(1953, 4, 8), 1529, datetime.datetime(2022, 2, 17, 19, 49, 33, 832587), datetime.datetime(2022, 2, 17, 19, 49, 33, 832589), '183.161.167.75')
# Ontario
# ('Grant Steele', 'nwebb@gmail.com', '831 Dwayne Meadow Suite 326', 'Meganberg', 'Ontario', 'American Samoa', '223-105-5549x6578', 'Area she market movie threat project ground fly accept goal seven time nothing.', datetime.date(1916, 7, 23), 1289, datetime.datetime(2022, 2, 17, 19, 49, 33, 833786), datetime.datetime(2022, 2, 17, 19, 49, 33, 833787), '214.25.248.97')
# New Brunswick
# ('William Lopez', 'hernandezstacy@hotmail.com', '356 Guzman Fall', 'Port Melissamouth', 'New Brunswick', 'American Samoa', '(294)012-8622', 'Guess plan young my thus end message.', datetime.date(1956, 5, 30), 2384, datetime.datetime(2022, 2, 17, 19, 49, 33, 838162), datetime.datetime(2022, 2, 17, 19, 49, 33, 838164), '148.248.110.0')
# Northwest Territories
# ('Bradley Peterson', 'cruzjason@gmail.com', '4376 Coffey Ways Suite 545', 'Williamview', 'Northwest Territories', 'Kuwait', '570-673-0456x5639', 'Stay opportunity himself source another need strategy animal.', datetime.date(1916, 10, 20), 1224, datetime.datetime(2022, 2, 17, 19, 49, 33, 840435), datetime.datetime(2022, 2, 17, 19, 49, 33, 840438), '22.120.175.85')
# Northwest Territories
# ('Denise Wright', 'lori02@hotmail.com', '20163 Richardson Springs Apt. 876', 'Turnerchester', 'Northwest Territories', 'Sweden', '(002)479-6372x54185', 'Computer and seat less occur must bag people.', datetime.date(2013, 1, 24), 2429, datetime.datetime(2022, 2, 17, 19, 49, 33, 841545), datetime.datetime(2022, 2, 17, 19, 49, 33, 841546), '207.23.14.29')
# Alberta
# ...
# Prince Edward Island
# ('Garrett Brown', 'jameswright@yahoo.com', '09213 Morales Loaf', 'Lake Kenneth', 'Prince Edward Island', 'Cambodia', '(887)668-5280x0217', 'Investment indeed maintain memory artist child choice which place.', datetime.date(1915, 7, 18), 1539, datetime.datetime(2022, 2, 17, 19, 49, 35, 568626), datetime.datetime(2022, 2, 17, 19, 49, 35, 568627), '112.191.67.37')
# Yukon
# ('James Duran', 'thomas95@hotmail.com', '362 Green Garden Apt. 145', 'Foxborough', 'Yukon', 'Heard Island and McDonald Islands', '001-671-755-7030x366', 'Attention pay somebody same important claim nice section note job painting.', datetime.date(1955, 9, 21), 1885, datetime.datetime(2022, 2, 17, 19, 49, 35, 570447), datetime.datetime(2022, 2, 17, 19, 49, 35, 570448), '171.71.248.99')
# Yukon
# ('Nicole Chapman', 'qschneider@gmail.com', '7807 Courtney Islands Suite 498', 'Reginaville', 'Yukon', 'Central African Republic', '4803545198', 'Stuff able cause think open bad officer.', datetime.date(1994, 12, 31), 2426, datetime.datetime(2022, 2, 17, 19, 49, 35, 572203), datetime.datetime(2022, 2, 17, 19, 49, 35, 572205), '223.72.241.83')
# Newfoundland and Labrador
# ('Nicholas Mata', 'johnharris@yahoo.com', '189 Gonzalez Field', 'Lake Mario', 'Newfoundland and Labrador', 'Nepal', '344-487-0497x0024', 'Fact with product kind practice exactly son player responsibility.', datetime.date(2004, 3, 21), 1920, datetime.datetime(2022, 2, 17, 19, 49, 35, 574087), datetime.datetime(2022, 2, 17, 19, 49, 35, 574089), '189.103.195.56')
# British Columbia
# ('Robert Scott', 'tracy60@gmail.com', '43990 Christopher Field Suite 201', 'Lake Hollyburgh', 'British Columbia', 'Romania', '058.969.8240x726', 'Laugh beat event magazine scene job grow nation yeah everybody prevent.', datetime.date(2016, 1, 2), 1533, datetime.datetime(2022, 2, 17, 19, 49, 35, 575308), datetime.datetime(2022, 2, 17, 19, 49, 35, 575309), '110.70.211.113')
# Nunavut
# ('John Diaz', 'stantonheather@hotmail.com', '248 Lori Circles Suite 636', 'East Kari', 'Nunavut', 'Iran', '001-152-884-0291', 'Work thousand entire fast serve reality its.', datetime.date(2006, 7, 25), 1946, datetime.datetime(2022, 2, 17, 19, 49, 35, 577601), datetime.datetime(2022, 2, 17, 19, 49, 35, 577602), '3.132.15.102')
# Alberta
# ('Richard Kim', 'omathis@gmail.com', '5012 Fischer Ramp Apt. 736', 'Kingfort', 'Alberta', 'Isle of Man', '(287)801-5589x472', 'Various truth budget goal similar away play create.', datetime.date(1950, 10, 18), 1932, datetime.datetime(2022, 2, 17, 19, 49, 35, 579402), datetime.datetime(2022, 2, 17, 19, 49, 35, 579403), '185.135.32.46')
# Prince Edward Island
# ('Craig Adams', 'matthewhodges@gmail.com', '38525 Peters Alley Suite 928', 'East Danielle', 'Prince Edward Island', 'Wallis and Futuna', '449.553.3398x39630', 'Could lawyer certain between still force east.', datetime.date(1997, 10, 4), 2319, datetime.datetime(2022, 2, 17, 19, 49, 35, 581335), datetime.datetime(2022, 2, 17, 19, 49, 35, 581336), '11.193.5.241')
# Yukon
# ('Alyssa Mora DDS', 'yolandaharris@gmail.com', '580 Olson Mission', 'West Allisonbury', 'Yukon', 'Angola', '001-010-313-6433x5808', 'Provide able mean minute human hour medical finally read end begin street college.', datetime.date(2010, 7, 17), 2007, datetime.datetime(2022, 2, 17, 19, 49, 35, 583133), datetime.datetime(2022, 2, 17, 19, 49, 35, 583134), '6.142.218.101')
# Newfoundland and Labrador
# ('Stephanie Nguyen', 'washingtonjoseph@hotmail.com', '3852 Lori Cliff', 'Ianhaven', 'Newfoundland and Labrador', 'Bangladesh', '(483)276-5280x47144', 'Few finally several chair so guy brother share suddenly role answer watch.', datetime.date(2009, 6, 20), 2489, datetime.datetime(2022, 2, 17, 19, 49, 35, 584857), datetime.datetime(2022, 2, 17, 19, 49, 35, 584858), '134.164.42.171')
# Nunavut
# ('Crystal Conley', 'mayoemily@hotmail.com', '636 George Street Suite 558', 'Johnathanshire', 'Nunavut', 'Madagascar', '001-074-892-6860x4537', 'Democratic hot radio address build may lawyer message.', datetime.date(1910, 5, 7), 1756, datetime.datetime(2022, 2, 17, 19, 49, 35, 586631), datetime.datetime(2022, 2, 17, 19, 49, 35, 586632), '211.84.175.192')
# Saskatchewan
# ('Terri Campbell', 'ielliott@hotmail.com', '73761 Chad Estates', 'Lake Mollymouth', 'Saskatchewan', 'Kyrgyz Republic', '200.259.8824x2907', 'By cost operation sister feel news current offer great just provide.', datetime.date(2005, 5, 13), 2334, datetime.datetime(2022, 2, 17, 19, 49, 35, 588378), datetime.datetime(2022, 2, 17, 19, 49, 35, 588380), '191.98.189.178')
# Ontario
# ('Cameron Brown', 'john69@yahoo.com', '0150 Lindsey Port', 'Lake Cheyenne', 'Ontario', 'Latvia', '001-114-942-5920x611', 'Statement speak mouth a better sense improve.', datetime.date(1925, 7, 17), 1448, datetime.datetime(2022, 2, 17, 19, 49, 35, 590048), datetime.datetime(2022, 2, 17, 19, 49, 35, 590050), '130.136.63.186')
# Northwest Territories
# ('Ashley Moyer', 'carrashley@gmail.com', '5116 Craig Estate', 'Kaitlynville', 'Northwest Territories', 'Tonga', '1609172331', 'Paper dog sometimes food left weight authority deal or trouble respond.', datetime.date(1917, 4, 13), 2130, datetime.datetime(2022, 2, 17, 19, 49, 35, 591809), datetime.datetime(2022, 2, 17, 19, 49, 35, 591810), '179.75.0.230')
# New Brunswick
# ('Colin Ryan', 'lori99@hotmail.com', '2631 Hart Point', 'South Robert', 'New Brunswick', 'Haiti', '+1-541-752-4914x5788', 'Hear visit air research eye more college.', datetime.date(2005, 8, 27), 1709, datetime.datetime(2022, 2, 17, 19, 49, 35, 593484), datetime.datetime(2022, 2, 17, 19, 49, 35, 593485), '144.40.172.125')
# Manitoba
# ('Thomas Long', 'timothy81@yahoo.com', '23858 William Way', 'Knightton', 'Manitoba', 'Bangladesh', '(642)900-2118', 'What face then authority value you today various discuss.', datetime.date(2011, 9, 6), 1654, datetime.datetime(2022, 2, 17, 19, 49, 35, 595200), datetime.datetime(2022, 2, 17, 19, 49, 35, 595202), '53.249.12.111')
# British Columbia
# ('Anna Perez', 'tlozano@gmail.com', '096 Brown Pines', 'West Ryanchester', 'British Columbia', 'Tokelau', '(029)217-1088', 'Experience include image on need majority what mouth material.', datetime.date(1923, 11, 19), 1820, datetime.datetime(2022, 2, 17, 19, 49, 35, 597722), datetime.datetime(2022, 2, 17, 19, 49, 35, 597723), '192.179.230.180')
# Quebec
# ('Linda Jones', 'bblevins@gmail.com', '725 Sarah Key', 'Allenville', 'Quebec', 'Puerto Rico', '578.592.3962x8549', 'Center successful fast partner glass quickly research maintain.', datetime.date(2020, 9, 7), 1086, datetime.datetime(2022, 2, 17, 19, 49, 35, 598699), datetime.datetime(2022, 2, 17, 19, 49, 35, 598700), '72.98.71.238')
# Prince Edward Island
# ('Scott Obrien', 'benjamin79@yahoo.com', '4770 Ann River Apt. 065', 'South Cindyfort', 'Prince Edward Island', 'Switzerland', '947-424-2965', 'Exactly kitchen young central board south by cup they.', datetime.date(2007, 8, 17), 1014, datetime.datetime(2022, 2, 17, 19, 49, 35, 600402), datetime.datetime(2022, 2, 17, 19, 49, 35, 600403), '12.119.52.157')
# Newfoundland and Labrador
# ('Carolyn Thompson', 'davidbrown@yahoo.com', '2920 Stacey Track Suite 245', 'Abigailhaven', 'Newfoundland and Labrador', 'Bermuda', '+1-288-010-2077x4742', 'Boy watch side involve involve report feel man film tend rock most another.', datetime.date(2014, 4, 3), 1633, datetime.datetime(2022, 2, 17, 19, 49, 35, 602940), datetime.datetime(2022, 2, 17, 19, 49, 35, 602942), '195.228.51.255')
# New Brunswick
# ('Joseph Watson', 'armstrongryan@gmail.com', '1980 Flores Parkways Suite 802', 'New Rickyside', 'New Brunswick', 'Hong Kong', '242.067.3849', 'Eat reflect over officer medical can raise future money threat.', datetime.date(1978, 7, 29), 1602, datetime.datetime(2022, 2, 17, 19, 49, 35, 603890), datetime.datetime(2022, 2, 17, 19, 49, 35, 603892), '201.85.90.41')
# Manitoba
# ('John Grant', 'tlong@yahoo.com', '363 Wanda Street Apt. 497', 'South Christina', 'Manitoba', 'Antarctica (the territory South of 60 deg S)', '565-669-9742x112', 'Part personal color speak discussion would resource character teach dream staff billion.', datetime.date(1965, 9, 26), 1983, datetime.datetime(2022, 2, 17, 19, 49, 35, 605606), datetime.datetime(2022, 2, 17, 19, 49, 35, 605608), '180.207.134.100')
# Newfoundland and Labrador
# ('Adrian Gilbert', 'taylorrachel@hotmail.com', '682 Schultz Mountain Suite 234', 'Stricklandport', 'Newfoundland and Labrador', 'Isle of Man', '(939)297-7644x125', 'Medical appear very police rock light brother PM road fund so age college.', datetime.date(1923, 4, 26), 2000, datetime.datetime(2022, 2, 17, 19, 49, 35, 607395), datetime.datetime(2022, 2, 17, 19, 49, 35, 607396), '220.220.66.97')
# Newfoundland and Labrador
# ('Tara Delacruz', 'kevinwilliams@yahoo.com', '7310 Teresa Circle', 'Smithland', 'Newfoundland and Labrador', 'Bulgaria', '+1-105-635-3623', 'Life them almost think single this interesting different deal military strong throughout.', datetime.date(1975, 4, 8), 1127, datetime.datetime(2022, 2, 17, 19, 49, 35, 609661), datetime.datetime(2022, 2, 17, 19, 49, 35, 609662), '170.57.216.153')
# Nunavut
# ('Veronica Holmes', 'qvaughn@gmail.com', '4196 Pope Spurs', 'North Christopher', 'Nunavut', 'Senegal', '7267803378', 'Detail score part determine still reveal test woman daughter also.', datetime.date(1996, 9, 11), 1446, datetime.datetime(2022, 2, 17, 19, 49, 35, 610915), datetime.datetime(2022, 2, 17, 19, 49, 35, 610916), '215.119.47.250')
# Ontario
# ('Katherine Arellano', 'michellenorris@gmail.com', '58713 Lewis Coves', 'North Michael', 'Ontario', 'Guinea', '001-158-059-2850x52321', 'Than foot lose part movement available attorney help institution little court participant.', datetime.date(1908, 10, 27), 2485, datetime.datetime(2022, 2, 17, 19, 49, 35, 612750), datetime.datetime(2022, 2, 17, 19, 49, 35, 612752), '95.229.29.162')
# British Columbia
# ('Kayla Carpenter', 'gregorymartin@gmail.com', '42840 Reyes Prairie', 'Robinland', 'British Columbia', 'Nepal', '511.193.7473', 'Senior need middle cost majority factor decade even.', datetime.date(1935, 11, 5), 1555, datetime.datetime(2022, 2, 17, 19, 49, 35, 614499), datetime.datetime(2022, 2, 17, 19, 49, 35, 614501), '16.28.194.132')
# Manitoba
# ('Tracey Gardner', 'brandonscott@gmail.com', '04386 Tucker Haven', 'New Steven', 'Manitoba', 'Panama', '+1-783-658-1036x3437', 'Billion recently stay democratic set remember night.', datetime.date(1925, 12, 1), 1753, datetime.datetime(2022, 2, 17, 19, 49, 35, 616290), datetime.datetime(2022, 2, 17, 19, 49, 35, 616291), '108.133.78.193')
# Manitoba
# ('Hannah Hatfield', 'yschultz@yahoo.com', '35998 James Plains Suite 243', 'East Ashleyshire', 'Manitoba', 'Palau', '(757)698-1001x6567', 'Card security computer teacher purpose experience budget mean relationship.', datetime.date(1968, 12, 6), 1378, datetime.datetime(2022, 2, 17, 19, 49, 35, 618163), datetime.datetime(2022, 2, 17, 19, 49, 35, 618164), '36.155.202.254')
# New Brunswick
# ('Steven Romero', 'spowers@gmail.com', '678 Jennifer Mission', 'South Matthew', 'New Brunswick', 'Antigua and Barbuda', '(838)520-4621', 'Simple different college every trade fire Republican current whose water full.', datetime.date(1993, 3, 6), 2330, datetime.datetime(2022, 2, 17, 19, 49, 35, 620037), datetime.datetime(2022, 2, 17, 19, 49, 35, 620038), '206.204.168.34')
# Saskatchewan
# ('Phyllis Benson', 'htorres@yahoo.com', '89946 Lucero Ranch', 'West Calvin', 'Saskatchewan', 'Ireland', '+1-413-280-2270', 'Like today know too relate much southern ahead think stuff clearly really town.', datetime.date(1951, 3, 4), 1331, datetime.datetime(2022, 2, 17, 19, 49, 35, 622318), datetime.datetime(2022, 2, 17, 19, 49, 35, 622319), '220.19.175.52')
# Nova Scotia
# ('Chad Ortega', 'nadams@hotmail.com', '7983 Goodman Grove', 'Port Kelli', 'Nova Scotia', 'Heard Island and McDonald Islands', '312-253-7769x158', 'Cover Congress own too knowledge decide everybody democratic so seat his laugh food.', datetime.date(1957, 8, 30), 1705, datetime.datetime(2022, 2, 17, 19, 49, 35, 624120), datetime.datetime(2022, 2, 17, 19, 49, 35, 624122), '140.89.143.212')
# Quebec
# ('Caroline Bailey', 'michaelallen@yahoo.com', '43856 Hill Trail', 'Paulstad', 'Quebec', 'Egypt', '472-925-9916x630', 'Skill least moment build matter remember employee much region human stay us.', datetime.date(1923, 12, 5), 1151, datetime.datetime(2022, 2, 17, 19, 49, 35, 626086), datetime.datetime(2022, 2, 17, 19, 49, 35, 626088), '190.212.144.241')
# Alberta
# ('Leslie Benson', 'ptaylor@yahoo.com', '142 Luna Views', 'Micheleland', 'Alberta', 'Guinea-Bissau', '(010)969-9974', 'Suddenly far nothing big few born give.', datetime.date(2015, 9, 12), 1615, datetime.datetime(2022, 2, 17, 19, 49, 35, 627870), datetime.datetime(2022, 2, 17, 19, 49, 35, 627871), '173.59.179.135')
# Newfoundland and Labrador
# ('Theresa Allen', 'myersmichael@yahoo.com', '0048 Chad Rapid', 'Port Williamborough', 'Newfoundland and Labrador', 'Reunion', '(137)870-7093', 'Through new believe by meet if occur for time finish really.', datetime.date(2020, 10, 19), 1537, datetime.datetime(2022, 2, 17, 19, 49, 35, 628769), datetime.datetime(2022, 2, 17, 19, 49, 35, 628770), '203.149.11.71')
# British Columbia
# ('Andrea Thompson', 'david65@gmail.com', '9989 Erica Mountains Apt. 628', 'East Matthew', 'British Columbia', 'Vanuatu', '(602)881-9032x33933', 'Once step budget present involve sure simple.', datetime.date(1946, 2, 26), 1778, datetime.datetime(2022, 2, 17, 19, 49, 35, 631325), datetime.datetime(2022, 2, 17, 19, 49, 35, 631326), '128.120.226.7')
# British Columbia
# ('Paul Smith', 'travishall@yahoo.com', '322 Rogers Knolls Suite 412', 'Hunterfurt', 'British Columbia', 'Andorra', '616.063.2835', 'She left rock hot rate political rich image role provide great next.', datetime.date(1933, 6, 4), 1905, datetime.datetime(2022, 2, 17, 19, 49, 35, 633172), datetime.datetime(2022, 2, 17, 19, 49, 35, 633173), '139.125.171.49')
# New Brunswick
# ('Erin Castro', 'ctaylor@hotmail.com', '61100 Chan Manors', 'Richardsonchester', 'New Brunswick', "Lao People's Democratic Republic", '179-426-1365x877', 'Every within book score attorney state example before spend hit person rise table.', datetime.date(1932, 4, 23), 1444, datetime.datetime(2022, 2, 17, 19, 49, 35, 635259), datetime.datetime(2022, 2, 17, 19, 49, 35, 635260), '89.193.255.39')
# New Brunswick
# ('John Cabrera', 'uallison@yahoo.com', '08030 Rachel Green Apt. 326', 'Brownfort', 'New Brunswick', 'Equatorial Guinea', '3809579801', 'Cultural pass something artist wall huge they.', datetime.date(1975, 5, 5), 1053, datetime.datetime(2022, 2, 17, 19, 49, 35, 637141), datetime.datetime(2022, 2, 17, 19, 49, 35, 637143), '71.159.32.139')
# Alberta
# ('Nancy Gonzalez', 'iboyle@hotmail.com', '1153 Amanda Club Suite 810', 'East Autumnburgh', 'Alberta', 'Luxembourg', '001-852-767-5938x667', 'East experience dinner those less trip education management.', datetime.date(1921, 6, 3), 2196, datetime.datetime(2022, 2, 17, 19, 49, 35, 639270), datetime.datetime(2022, 2, 17, 19, 49, 35, 639271), '27.225.201.223')
# Manitoba
# ('Dr. Stephanie Smith', 'ogillespie@hotmail.com', '24827 Sandoval Crest Suite 901', 'Anthonybury', 'Manitoba', 'Swaziland', '292-327-2726x01540', 'Win already free page attention fact debate game time news of others kind.', datetime.date(2004, 1, 8), 2378, datetime.datetime(2022, 2, 17, 19, 49, 35, 641107), datetime.datetime(2022, 2, 17, 19, 49, 35, 641109), '219.134.125.201')
# British Columbia
# ('Sandy Stone', 'qhernandez@yahoo.com', '0196 Houston Alley Apt. 085', 'Bruceville', 'British Columbia', 'Tanzania', '(374)958-4956x56930', 'Concern reach blood body city scene way local I simple not far economy.', datetime.date(1962, 4, 25), 2324, datetime.datetime(2022, 2, 17, 19, 49, 35, 642986), datetime.datetime(2022, 2, 17, 19, 49, 35, 642988), '208.228.214.100')

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
import pprint

pp = pprint.PrettyPrinter()
#Retreive the Connection object
conn = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
c = conn.cursor()
c.execute("""SELECT name, heatmap FROM people WHERE heatmap > 1500 LIMIT 20
""")
results = c.fetchall()


pp.pprint(results)
conn.close()
# Out:
# [('Patrick Barber', 2070),
#  ('John Morris', 2115),
#  ('Taylor Chambers', 1593),
#  ('Kimberly Zuniga', 1844),
#  ('Kathleen Lara DDS', 1906),
#  ('David Fisher DDS', 1748),
#  ('Jodi Holder', 2250),
#  ('Bryan Chan', 2373),
#  ('Lisa Martin', 1842),
#  ('Brandon Cruz', 2459),
#  ('Carolyn Guzman', 1777),
#  ('Juan Goodwin', 2046),
#  ('Douglas Patton', 1662),
#  ('Tiffany Hamilton', 1886),
#  ('Kenneth Miller', 1670),
#  ('Mrs. Carolyn Harper', 1819),
#  ('Jeremy Nguyen', 2024),
#  ('David Jones', 1661),
#  ('Mr. Clayton Gomez', 2090),
#  ('Tyler Bishop', 1857)]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
