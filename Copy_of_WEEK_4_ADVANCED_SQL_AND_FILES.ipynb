# %% [markdown]
# <a href="https://colab.research.google.com/github/BrandanWood/COMP593/blob/lab-4/Copy_of_WEEK_4_ADVANCED_SQL_AND_FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fecc2734-91f6-430f-8e9b-b5091f12ab4e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fecc2734-91f6-430f-8e9b-b5091f12ab4e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network.db to social_network.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                         id integer PRIMARY KEY NOT NULL,
                         user_id integer NOT NULL,
                         friend_id integer NOT NULL,
                         date_created DATE NOT NULL,
                         FOREIGN KEY (user_id) REFERENCES people (id),
                         FOREIGN KEY (friend_id) REFERENCES people (id)
                        );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %%
# make sure stuff was added properly
conn = sqlite3.connect('social_network.db')
c = conn.cursor()

c.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('relationships')")
print(c.fetchone())
conn.close
# Out:
# ('id, user_id, friend_id, date_created',)
# <function Connection.close>

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
conn = sqlite3.connect('social_network.db')

c = conn.cursor()

#Complete the below query
query =  """INSERT INTO relationships (
            user_id,
            friend_id,
            date_created)
         VALUES (?, ?, ?);"""

for _ in range(1000):
  #Populate the arguments that will be used in the query
  args = (
      randrange(1, 1001),
      randrange(1, 1001),
      datetime.now()
   )
  #Execute the query
  c.execute(query, args)
  print(args)

#Commit your changes and close the connection.
conn.commit()
conn.close()
# Out:
# (982, 64, datetime.datetime(2022, 2, 28, 17, 11, 10, 946026))
# (393, 692, datetime.datetime(2022, 2, 28, 17, 11, 10, 946418))
# (652, 314, datetime.datetime(2022, 2, 28, 17, 11, 10, 946465))
# (808, 528, datetime.datetime(2022, 2, 28, 17, 11, 10, 946503))
# (186, 712, datetime.datetime(2022, 2, 28, 17, 11, 10, 946543))
# (76, 868, datetime.datetime(2022, 2, 28, 17, 11, 10, 946582))
# (666, 909, datetime.datetime(2022, 2, 28, 17, 11, 10, 946623))
# (613, 633, datetime.datetime(2022, 2, 28, 17, 11, 10, 946699))
# (318, 605, datetime.datetime(2022, 2, 28, 17, 11, 10, 946745))
# (286, 192, datetime.datetime(2022, 2, 28, 17, 11, 10, 946784))
# (183, 327, datetime.datetime(2022, 2, 28, 17, 11, 10, 946817))
# (847, 812, datetime.datetime(2022, 2, 28, 17, 11, 10, 946848))
# (960, 823, datetime.datetime(2022, 2, 28, 17, 11, 10, 946879))
# (324, 268, datetime.datetime(2022, 2, 28, 17, 11, 10, 946909))
# (954, 623, datetime.datetime(2022, 2, 28, 17, 11, 10, 946942))
# (442, 596, datetime.datetime(2022, 2, 28, 17, 11, 10, 947358))
# (740, 514, datetime.datetime(2022, 2, 28, 17, 11, 10, 947411))
# (670, 697, datetime.datetime(2022, 2, 28, 17, 11, 10, 947447))
# (519, 13, datetime.datetime(2022, 2, 28, 17, 11, 10, 947485))
# (805, 552, datetime.datetime(2022, 2, 28, 17, 11, 10, 947524))
# (472, 833, datetime.datetime(2022, 2, 28, 17, 11, 10, 947562))
# (323, 851, datetime.datetime(2022, 2, 28, 17, 11, 10, 947595))
# (27, 927, datetime.datetime(2022, 2, 28, 17, 11, 10, 947629))
# (20, 233, datetime.datetime(2022, 2, 28, 17, 11, 10, 947683))
# (684, 374, datetime.datetime(2022, 2, 28, 17, 11, 10, 947721))
# (129, 536, datetime.datetime(2022, 2, 28, 17, 11, 10, 947757))
# (606, 853, datetime.datetime(2022, 2, 28, 17, 11, 10, 947788))
# (854, 399, datetime.datetime(2022, 2, 28, 17, 11, 10, 947818))
# (78, 823, datetime.datetime(2022, 2, 28, 17, 11, 10, 947892))
# (787, 880, datetime.datetime(2022, 2, 28, 17, 11, 10, 947965))
# (538, 198, datetime.datetime(2022, 2, 28, 17, 11, 10, 948005))
# (32, 366, datetime.datetime(2022, 2, 28, 17, 11, 10, 948958))
# (98, 473, datetime.datetime(2022, 2, 28, 17, 11, 10, 949015))
# (859, 796, datetime.datetime(2022, 2, 28, 17, 11, 10, 949054))
# (858, 129, datetime.datetime(2022, 2, 28, 17, 11, 10, 949096))
# (180, 936, datetime.datetime(2022, 2, 28, 17, 11, 10, 949126))
# (799, 20, datetime.datetime(2022, 2, 28, 17, 11, 10, 949156))
# (278, 529, datetime.datetime(2022, 2, 28, 17, 11, 10, 949188))
# (296, 998, datetime.datetime(2022, 2, 28, 17, 11, 10, 949217))
# (865, 804, datetime.datetime(2022, 2, 28, 17, 11, 10, 949243))
# (917, 644, datetime.datetime(2022, 2, 28, 17, 11, 10, 949265))
# (717, 790, datetime.datetime(2022, 2, 28, 17, 11, 10, 949286))
# (109, 189, datetime.datetime(2022, 2, 28, 17, 11, 10, 949307))
# (556, 643, datetime.datetime(2022, 2, 28, 17, 11, 10, 949327))
# (65, 791, datetime.datetime(2022, 2, 28, 17, 11, 10, 949346))
# (892, 317, datetime.datetime(2022, 2, 28, 17, 11, 10, 949366))
# (514, 219, datetime.datetime(2022, 2, 28, 17, 11, 10, 949386))
# (911, 545, datetime.datetime(2022, 2, 28, 17, 11, 10, 949406))
# (564, 685, datetime.datetime(2022, 2, 28, 17, 11, 10, 949426))
# (882, 409, datetime.datetime(2022, 2, 28, 17, 11, 10, 949448))
# (423, 388, datetime.datetime(2022, 2, 28, 17, 11, 10, 949478))
# (194, 861, datetime.datetime(2022, 2, 28, 17, 11, 10, 949505))
# (873, 504, datetime.datetime(2022, 2, 28, 17, 11, 10, 949533))
# (965, 827, datetime.datetime(2022, 2, 28, 17, 11, 10, 949564))
# (715, 557, datetime.datetime(2022, 2, 28, 17, 11, 10, 949585))
# (635, 692, datetime.datetime(2022, 2, 28, 17, 11, 10, 949604))
# (607, 429, datetime.datetime(2022, 2, 28, 17, 11, 10, 949624))
# (85, 277, datetime.datetime(2022, 2, 28, 17, 11, 10, 949643))
# (902, 354, datetime.datetime(2022, 2, 28, 17, 11, 10, 949695))
# (707, 134, datetime.datetime(2022, 2, 28, 17, 11, 10, 949723))
# (291, 823, datetime.datetime(2022, 2, 28, 17, 11, 10, 949744))
# (468, 347, datetime.datetime(2022, 2, 28, 17, 11, 10, 949764))
# (937, 615, datetime.datetime(2022, 2, 28, 17, 11, 10, 949784))
# (349, 47, datetime.datetime(2022, 2, 28, 17, 11, 10, 949804))
# (933, 73, datetime.datetime(2022, 2, 28, 17, 11, 10, 949825))
# (588, 345, datetime.datetime(2022, 2, 28, 17, 11, 10, 949846))
# (974, 926, datetime.datetime(2022, 2, 28, 17, 11, 10, 949867))
# (472, 39, datetime.datetime(2022, 2, 28, 17, 11, 10, 949887))
# (367, 821, datetime.datetime(2022, 2, 28, 17, 11, 10, 949907))
# (34, 168, datetime.datetime(2022, 2, 28, 17, 11, 10, 949927))
# (634, 233, datetime.datetime(2022, 2, 28, 17, 11, 10, 949948))
# (103, 588, datetime.datetime(2022, 2, 28, 17, 11, 10, 949969))
# (56, 866, datetime.datetime(2022, 2, 28, 17, 11, 10, 949989))
# (190, 96, datetime.datetime(2022, 2, 28, 17, 11, 10, 950010))
# (996, 864, datetime.datetime(2022, 2, 28, 17, 11, 10, 950030))
# (50, 992, datetime.datetime(2022, 2, 28, 17, 11, 10, 950052))
# (364, 622, datetime.datetime(2022, 2, 28, 17, 11, 10, 950091))
# (831, 392, datetime.datetime(2022, 2, 28, 17, 11, 10, 950117))
# (733, 238, datetime.datetime(2022, 2, 28, 17, 11, 10, 950137))
# (471, 150, datetime.datetime(2022, 2, 28, 17, 11, 10, 950163))
# (779, 993, datetime.datetime(2022, 2, 28, 17, 11, 10, 950184))
# (760, 414, datetime.datetime(2022, 2, 28, 17, 11, 10, 950204))
# (297, 787, datetime.datetime(2022, 2, 28, 17, 11, 10, 950224))
# (613, 138, datetime.datetime(2022, 2, 28, 17, 11, 10, 950244))
# (892, 675, datetime.datetime(2022, 2, 28, 17, 11, 10, 950264))
# (63, 261, datetime.datetime(2022, 2, 28, 17, 11, 10, 950283))
# (735, 251, datetime.datetime(2022, 2, 28, 17, 11, 10, 950303))
# (623, 906, datetime.datetime(2022, 2, 28, 17, 11, 10, 950323))
# (202, 123, datetime.datetime(2022, 2, 28, 17, 11, 10, 950343))
# (758, 372, datetime.datetime(2022, 2, 28, 17, 11, 10, 950363))
# (774, 947, datetime.datetime(2022, 2, 28, 17, 11, 10, 950382))
# (496, 674, datetime.datetime(2022, 2, 28, 17, 11, 10, 950401))
# (873, 893, datetime.datetime(2022, 2, 28, 17, 11, 10, 950423))
# (989, 905, datetime.datetime(2022, 2, 28, 17, 11, 10, 950449))
# (516, 777, datetime.datetime(2022, 2, 28, 17, 11, 10, 950469))
# (881, 584, datetime.datetime(2022, 2, 28, 17, 11, 10, 950489))
# (870, 353, datetime.datetime(2022, 2, 28, 17, 11, 10, 950509))
# (481, 514, datetime.datetime(2022, 2, 28, 17, 11, 10, 950529))
# (335, 279, datetime.datetime(2022, 2, 28, 17, 11, 10, 950548))
# (371, 407, datetime.datetime(2022, 2, 28, 17, 11, 10, 950569))
# (426, 189, datetime.datetime(2022, 2, 28, 17, 11, 10, 950677))
# (862, 844, datetime.datetime(2022, 2, 28, 17, 11, 10, 950711))
# (298, 713, datetime.datetime(2022, 2, 28, 17, 11, 10, 950734))
# (751, 500, datetime.datetime(2022, 2, 28, 17, 11, 10, 950754))
# (657, 780, datetime.datetime(2022, 2, 28, 17, 11, 10, 950774))
# (510, 280, datetime.datetime(2022, 2, 28, 17, 11, 10, 950793))
# (892, 730, datetime.datetime(2022, 2, 28, 17, 11, 10, 950865))
# (615, 544, datetime.datetime(2022, 2, 28, 17, 11, 10, 950888))
# (335, 207, datetime.datetime(2022, 2, 28, 17, 11, 10, 950908))
# (872, 858, datetime.datetime(2022, 2, 28, 17, 11, 10, 950928))
# (92, 335, datetime.datetime(2022, 2, 28, 17, 11, 10, 950948))
# (439, 571, datetime.datetime(2022, 2, 28, 17, 11, 10, 950969))
# (685, 763, datetime.datetime(2022, 2, 28, 17, 11, 10, 950989))
# (54, 940, datetime.datetime(2022, 2, 28, 17, 11, 10, 951009))
# (854, 588, datetime.datetime(2022, 2, 28, 17, 11, 10, 951029))
# (820, 96, datetime.datetime(2022, 2, 28, 17, 11, 10, 951049))
# (957, 169, datetime.datetime(2022, 2, 28, 17, 11, 10, 951069))
# (783, 798, datetime.datetime(2022, 2, 28, 17, 11, 10, 951098))
# (339, 271, datetime.datetime(2022, 2, 28, 17, 11, 10, 951118))
# (121, 163, datetime.datetime(2022, 2, 28, 17, 11, 10, 951138))
# (119, 160, datetime.datetime(2022, 2, 28, 17, 11, 10, 951158))
# (555, 769, datetime.datetime(2022, 2, 28, 17, 11, 10, 951178))
# (253, 280, datetime.datetime(2022, 2, 28, 17, 11, 10, 951198))
# (973, 99, datetime.datetime(2022, 2, 28, 17, 11, 10, 951218))
# (367, 526, datetime.datetime(2022, 2, 28, 17, 11, 10, 951242))
# (394, 457, datetime.datetime(2022, 2, 28, 17, 11, 10, 951262))
# (265, 275, datetime.datetime(2022, 2, 28, 17, 11, 10, 951281))
# (649, 280, datetime.datetime(2022, 2, 28, 17, 11, 10, 951303))
# (615, 129, datetime.datetime(2022, 2, 28, 17, 11, 10, 951323))
# (863, 331, datetime.datetime(2022, 2, 28, 17, 11, 10, 951348))
# (398, 122, datetime.datetime(2022, 2, 28, 17, 11, 10, 951369))
# (334, 323, datetime.datetime(2022, 2, 28, 17, 11, 10, 951389))
# (116, 401, datetime.datetime(2022, 2, 28, 17, 11, 10, 951409))
# (333, 801, datetime.datetime(2022, 2, 28, 17, 11, 10, 951428))
# (507, 344, datetime.datetime(2022, 2, 28, 17, 11, 10, 951448))
# (920, 937, datetime.datetime(2022, 2, 28, 17, 11, 10, 951467))
# (636, 369, datetime.datetime(2022, 2, 28, 17, 11, 10, 951487))
# (919, 613, datetime.datetime(2022, 2, 28, 17, 11, 10, 951506))
# (874, 252, datetime.datetime(2022, 2, 28, 17, 11, 10, 951525))
# (629, 698, datetime.datetime(2022, 2, 28, 17, 11, 10, 951545))
# (390, 557, datetime.datetime(2022, 2, 28, 17, 11, 10, 951568))
# (810, 325, datetime.datetime(2022, 2, 28, 17, 11, 10, 951589))
# (454, 514, datetime.datetime(2022, 2, 28, 17, 11, 10, 951609))
# (369, 740, datetime.datetime(2022, 2, 28, 17, 11, 10, 951632))
# (416, 318, datetime.datetime(2022, 2, 28, 17, 11, 10, 951689))
# (502, 148, datetime.datetime(2022, 2, 28, 17, 11, 10, 953034))
# (485, 310, datetime.datetime(2022, 2, 28, 17, 11, 10, 953728))
# (396, 342, datetime.datetime(2022, 2, 28, 17, 11, 10, 959925))
# (92, 961, datetime.datetime(2022, 2, 28, 17, 11, 10, 962846))
# (17, 432, datetime.datetime(2022, 2, 28, 17, 11, 10, 963708))
# (600, 746, datetime.datetime(2022, 2, 28, 17, 11, 10, 966158))
# (656, 171, datetime.datetime(2022, 2, 28, 17, 11, 10, 966566))
# (387, 432, datetime.datetime(2022, 2, 28, 17, 11, 10, 967306))
# (266, 408, datetime.datetime(2022, 2, 28, 17, 11, 10, 967369))
# (20, 105, datetime.datetime(2022, 2, 28, 17, 11, 10, 968095))
# (482, 27, datetime.datetime(2022, 2, 28, 17, 11, 10, 969532))
# (363, 246, datetime.datetime(2022, 2, 28, 17, 11, 10, 971282))
# (525, 29, datetime.datetime(2022, 2, 28, 17, 11, 10, 972476))
# (214, 649, datetime.datetime(2022, 2, 28, 17, 11, 10, 976194))
# (386, 690, datetime.datetime(2022, 2, 28, 17, 11, 10, 977282))
# (19, 664, datetime.datetime(2022, 2, 28, 17, 11, 10, 978833))
# (392, 102, datetime.datetime(2022, 2, 28, 17, 11, 10, 979073))
# (639, 339, datetime.datetime(2022, 2, 28, 17, 11, 10, 980415))
# (332, 444, datetime.datetime(2022, 2, 28, 17, 11, 10, 981736))
# (908, 361, datetime.datetime(2022, 2, 28, 17, 11, 10, 982798))
# (841, 378, datetime.datetime(2022, 2, 28, 17, 11, 10, 985083))
# (154, 834, datetime.datetime(2022, 2, 28, 17, 11, 10, 985825))
# (518, 637, datetime.datetime(2022, 2, 28, 17, 11, 10, 987519))
# (313, 206, datetime.datetime(2022, 2, 28, 17, 11, 10, 987952))
# (588, 865, datetime.datetime(2022, 2, 28, 17, 11, 10, 989277))
# (687, 709, datetime.datetime(2022, 2, 28, 17, 11, 10, 989339))
# (993, 757, datetime.datetime(2022, 2, 28, 17, 11, 10, 990715))
# (681, 155, datetime.datetime(2022, 2, 28, 17, 11, 10, 992207))
# (736, 952, datetime.datetime(2022, 2, 28, 17, 11, 10, 993991))
# (961, 942, datetime.datetime(2022, 2, 28, 17, 11, 10, 995632))
# (307, 160, datetime.datetime(2022, 2, 28, 17, 11, 10, 996979))
# (731, 159, datetime.datetime(2022, 2, 28, 17, 11, 11, 1943))
# (214, 199, datetime.datetime(2022, 2, 28, 17, 11, 11, 3013))
# (2, 394, datetime.datetime(2022, 2, 28, 17, 11, 11, 3759))
# (846, 354, datetime.datetime(2022, 2, 28, 17, 11, 11, 3821))
# (224, 369, datetime.datetime(2022, 2, 28, 17, 11, 11, 4216))
# (299, 127, datetime.datetime(2022, 2, 28, 17, 11, 11, 4276))
# (379, 683, datetime.datetime(2022, 2, 28, 17, 11, 11, 5008))
# (280, 433, datetime.datetime(2022, 2, 28, 17, 11, 11, 6359))
# (875, 29, datetime.datetime(2022, 2, 28, 17, 11, 11, 6419))
# (143, 322, datetime.datetime(2022, 2, 28, 17, 11, 11, 7433))
# (115, 837, datetime.datetime(2022, 2, 28, 17, 11, 11, 7494))
# (957, 326, datetime.datetime(2022, 2, 28, 17, 11, 11, 9439))
# (666, 282, datetime.datetime(2022, 2, 28, 17, 11, 11, 10774))
# (350, 233, datetime.datetime(2022, 2, 28, 17, 11, 11, 13743))
# (525, 594, datetime.datetime(2022, 2, 28, 17, 11, 11, 15369))
# (752, 68, datetime.datetime(2022, 2, 28, 17, 11, 11, 16215))
# (38, 818, datetime.datetime(2022, 2, 28, 17, 11, 11, 16610))
# (653, 741, datetime.datetime(2022, 2, 28, 17, 11, 11, 17929))
# (783, 894, datetime.datetime(2022, 2, 28, 17, 11, 11, 18635))
# (293, 318, datetime.datetime(2022, 2, 28, 17, 11, 11, 18722))
# (189, 678, datetime.datetime(2022, 2, 28, 17, 11, 11, 19117))
# (739, 187, datetime.datetime(2022, 2, 28, 17, 11, 11, 20309))
# (791, 493, datetime.datetime(2022, 2, 28, 17, 11, 11, 20370))
# (628, 936, datetime.datetime(2022, 2, 28, 17, 11, 11, 21102))
# (425, 439, datetime.datetime(2022, 2, 28, 17, 11, 11, 21496))
# (429, 140, datetime.datetime(2022, 2, 28, 17, 11, 11, 21905))
# (961, 428, datetime.datetime(2022, 2, 28, 17, 11, 11, 22305))
# (886, 598, datetime.datetime(2022, 2, 28, 17, 11, 11, 22735))
# (236, 535, datetime.datetime(2022, 2, 28, 17, 11, 11, 23124))
# (86, 37, datetime.datetime(2022, 2, 28, 17, 11, 11, 23517))
# (646, 53, datetime.datetime(2022, 2, 28, 17, 11, 11, 23925))
# (305, 509, datetime.datetime(2022, 2, 28, 17, 11, 11, 23988))
# (218, 446, datetime.datetime(2022, 2, 28, 17, 11, 11, 24724))
# (287, 901, datetime.datetime(2022, 2, 28, 17, 11, 11, 25127))
# (479, 226, datetime.datetime(2022, 2, 28, 17, 11, 11, 25527))
# (277, 128, datetime.datetime(2022, 2, 28, 17, 11, 11, 25934))
# (872, 722, datetime.datetime(2022, 2, 28, 17, 11, 11, 26329))
# (997, 607, datetime.datetime(2022, 2, 28, 17, 11, 11, 26744))
# (469, 480, datetime.datetime(2022, 2, 28, 17, 11, 11, 27148))
# (987, 423, datetime.datetime(2022, 2, 28, 17, 11, 11, 27549))
# (936, 652, datetime.datetime(2022, 2, 28, 17, 11, 11, 27953))
# (224, 938, datetime.datetime(2022, 2, 28, 17, 11, 11, 28356))
# (629, 938, datetime.datetime(2022, 2, 28, 17, 11, 11, 28418))
# (611, 352, datetime.datetime(2022, 2, 28, 17, 11, 11, 29237))
# (575, 963, datetime.datetime(2022, 2, 28, 17, 11, 11, 29640))
# (204, 962, datetime.datetime(2022, 2, 28, 17, 11, 11, 30064))
# (433, 222, datetime.datetime(2022, 2, 28, 17, 11, 11, 30464))
# (149, 550, datetime.datetime(2022, 2, 28, 17, 11, 11, 30527))
# (471, 22, datetime.datetime(2022, 2, 28, 17, 11, 11, 31251))
# (774, 72, datetime.datetime(2022, 2, 28, 17, 11, 11, 31666))
# (248, 631, datetime.datetime(2022, 2, 28, 17, 11, 11, 32053))
# (150, 821, datetime.datetime(2022, 2, 28, 17, 11, 11, 32442))
# (72, 737, datetime.datetime(2022, 2, 28, 17, 11, 11, 33002))
# (141, 570, datetime.datetime(2022, 2, 28, 17, 11, 11, 33065))
# (401, 331, datetime.datetime(2022, 2, 28, 17, 11, 11, 33583))
# (323, 115, datetime.datetime(2022, 2, 28, 17, 11, 11, 33986))
# (771, 443, datetime.datetime(2022, 2, 28, 17, 11, 11, 34374))
# (215, 418, datetime.datetime(2022, 2, 28, 17, 11, 11, 34433))
# (250, 551, datetime.datetime(2022, 2, 28, 17, 11, 11, 35142))
# (471, 194, datetime.datetime(2022, 2, 28, 17, 11, 11, 35528))
# (852, 150, datetime.datetime(2022, 2, 28, 17, 11, 11, 35588))
# (226, 757, datetime.datetime(2022, 2, 28, 17, 11, 11, 36311))
# (207, 957, datetime.datetime(2022, 2, 28, 17, 11, 11, 36715))
# (325, 2, datetime.datetime(2022, 2, 28, 17, 11, 11, 37108))
# (755, 47, datetime.datetime(2022, 2, 28, 17, 11, 11, 37496))
# (423, 136, datetime.datetime(2022, 2, 28, 17, 11, 11, 37923))
# (477, 167, datetime.datetime(2022, 2, 28, 17, 11, 11, 38318))
# (681, 12, datetime.datetime(2022, 2, 28, 17, 11, 11, 38716))
# (403, 991, datetime.datetime(2022, 2, 28, 17, 11, 11, 38775))
# (373, 507, datetime.datetime(2022, 2, 28, 17, 11, 11, 39460))
# (265, 758, datetime.datetime(2022, 2, 28, 17, 11, 11, 39876))
# (439, 839, datetime.datetime(2022, 2, 28, 17, 11, 11, 40259))
# (430, 378, datetime.datetime(2022, 2, 28, 17, 11, 11, 40645))
# (299, 756, datetime.datetime(2022, 2, 28, 17, 11, 11, 41046))
# (396, 509, datetime.datetime(2022, 2, 28, 17, 11, 11, 41429))
# (140, 829, datetime.datetime(2022, 2, 28, 17, 11, 11, 41841))
# (354, 515, datetime.datetime(2022, 2, 28, 17, 11, 11, 41900))
# (420, 500, datetime.datetime(2022, 2, 28, 17, 11, 11, 42580))
# (68, 495, datetime.datetime(2022, 2, 28, 17, 11, 11, 42992))
# (246, 250, datetime.datetime(2022, 2, 28, 17, 11, 11, 43051))
# (136, 709, datetime.datetime(2022, 2, 28, 17, 11, 11, 43752))
# (238, 889, datetime.datetime(2022, 2, 28, 17, 11, 11, 44594))
# (946, 813, datetime.datetime(2022, 2, 28, 17, 11, 11, 45252))
# (257, 870, datetime.datetime(2022, 2, 28, 17, 11, 11, 46081))
# (355, 125, datetime.datetime(2022, 2, 28, 17, 11, 11, 46868))
# (91, 943, datetime.datetime(2022, 2, 28, 17, 11, 11, 47091))
# (519, 340, datetime.datetime(2022, 2, 28, 17, 11, 11, 47500))
# (293, 469, datetime.datetime(2022, 2, 28, 17, 11, 11, 47561))
# (904, 781, datetime.datetime(2022, 2, 28, 17, 11, 11, 47713))
# (144, 402, datetime.datetime(2022, 2, 28, 17, 11, 11, 48670))
# (918, 339, datetime.datetime(2022, 2, 28, 17, 11, 11, 49645))
# (213, 94, datetime.datetime(2022, 2, 28, 17, 11, 11, 50239))
# (274, 413, datetime.datetime(2022, 2, 28, 17, 11, 11, 50783))
# (599, 426, datetime.datetime(2022, 2, 28, 17, 11, 11, 51207))
# (73, 656, datetime.datetime(2022, 2, 28, 17, 11, 11, 51267))
# (139, 569, datetime.datetime(2022, 2, 28, 17, 11, 11, 51985))
# (313, 194, datetime.datetime(2022, 2, 28, 17, 11, 11, 52048))
# (25, 342, datetime.datetime(2022, 2, 28, 17, 11, 11, 52102))
# (43, 992, datetime.datetime(2022, 2, 28, 17, 11, 11, 53140))
# (730, 10, datetime.datetime(2022, 2, 28, 17, 11, 11, 53534))
# (654, 150, datetime.datetime(2022, 2, 28, 17, 11, 11, 53935))
# (50, 621, datetime.datetime(2022, 2, 28, 17, 11, 11, 54668))
# (123, 247, datetime.datetime(2022, 2, 28, 17, 11, 11, 54736))
# (844, 357, datetime.datetime(2022, 2, 28, 17, 11, 11, 55269))
# (982, 811, datetime.datetime(2022, 2, 28, 17, 11, 11, 55844))
# (391, 288, datetime.datetime(2022, 2, 28, 17, 11, 11, 56070))
# (324, 59, datetime.datetime(2022, 2, 28, 17, 11, 11, 56127))
# (153, 691, datetime.datetime(2022, 2, 28, 17, 11, 11, 56842))
# (854, 168, datetime.datetime(2022, 2, 28, 17, 11, 11, 57235))
# (379, 826, datetime.datetime(2022, 2, 28, 17, 11, 11, 57623))
# (243, 966, datetime.datetime(2022, 2, 28, 17, 11, 11, 58019))
# (935, 355, datetime.datetime(2022, 2, 28, 17, 11, 11, 58742))
# (648, 285, datetime.datetime(2022, 2, 28, 17, 11, 11, 58816))
# (720, 652, datetime.datetime(2022, 2, 28, 17, 11, 11, 59210))
# (311, 442, datetime.datetime(2022, 2, 28, 17, 11, 11, 59606))
# (498, 11, datetime.datetime(2022, 2, 28, 17, 11, 11, 60027))
# (978, 532, datetime.datetime(2022, 2, 28, 17, 11, 11, 60415))
# (226, 695, datetime.datetime(2022, 2, 28, 17, 11, 11, 60835))
# (27, 733, datetime.datetime(2022, 2, 28, 17, 11, 11, 60895))
# (91, 512, datetime.datetime(2022, 2, 28, 17, 11, 11, 61288))
# (377, 286, datetime.datetime(2022, 2, 28, 17, 11, 11, 62002))
# (699, 168, datetime.datetime(2022, 2, 28, 17, 11, 11, 63108))
# (592, 410, datetime.datetime(2022, 2, 28, 17, 11, 11, 63394))
# (131, 291, datetime.datetime(2022, 2, 28, 17, 11, 11, 63826))
# (317, 791, datetime.datetime(2022, 2, 28, 17, 11, 11, 64247))
# (73, 802, datetime.datetime(2022, 2, 28, 17, 11, 11, 64671))
# (97, 870, datetime.datetime(2022, 2, 28, 17, 11, 11, 65080))
# (171, 305, datetime.datetime(2022, 2, 28, 17, 11, 11, 66014))
# (241, 533, datetime.datetime(2022, 2, 28, 17, 11, 11, 66093))
# (230, 698, datetime.datetime(2022, 2, 28, 17, 11, 11, 66553))
# (102, 543, datetime.datetime(2022, 2, 28, 17, 11, 11, 67218))
# (877, 296, datetime.datetime(2022, 2, 28, 17, 11, 11, 67280))
# (272, 554, datetime.datetime(2022, 2, 28, 17, 11, 11, 68157))
# (456, 974, datetime.datetime(2022, 2, 28, 17, 11, 11, 68219))
# (941, 338, datetime.datetime(2022, 2, 28, 17, 11, 11, 68931))
# (267, 974, datetime.datetime(2022, 2, 28, 17, 11, 11, 69335))
# (927, 425, datetime.datetime(2022, 2, 28, 17, 11, 11, 69740))
# (173, 972, datetime.datetime(2022, 2, 28, 17, 11, 11, 70131))
# (480, 723, datetime.datetime(2022, 2, 28, 17, 11, 11, 70521))
# (756, 952, datetime.datetime(2022, 2, 28, 17, 11, 11, 70923))
# (572, 367, datetime.datetime(2022, 2, 28, 17, 11, 11, 71319))
# (742, 544, datetime.datetime(2022, 2, 28, 17, 11, 11, 71379))
# (548, 434, datetime.datetime(2022, 2, 28, 17, 11, 11, 72076))
# (451, 508, datetime.datetime(2022, 2, 28, 17, 11, 11, 72534))
# (345, 343, datetime.datetime(2022, 2, 28, 17, 11, 11, 72575))
# (892, 931, datetime.datetime(2022, 2, 28, 17, 11, 11, 72608))
# (880, 105, datetime.datetime(2022, 2, 28, 17, 11, 11, 72643))
# (549, 410, datetime.datetime(2022, 2, 28, 17, 11, 11, 72738))
# (295, 800, datetime.datetime(2022, 2, 28, 17, 11, 11, 74535))
# (939, 87, datetime.datetime(2022, 2, 28, 17, 11, 11, 74786))
# (909, 794, datetime.datetime(2022, 2, 28, 17, 11, 11, 75182))
# (725, 922, datetime.datetime(2022, 2, 28, 17, 11, 11, 75582))
# (426, 109, datetime.datetime(2022, 2, 28, 17, 11, 11, 76007))
# (170, 975, datetime.datetime(2022, 2, 28, 17, 11, 11, 76405))
# (13, 539, datetime.datetime(2022, 2, 28, 17, 11, 11, 76817))
# (433, 591, datetime.datetime(2022, 2, 28, 17, 11, 11, 77206))
# (294, 582, datetime.datetime(2022, 2, 28, 17, 11, 11, 77595))
# (289, 263, datetime.datetime(2022, 2, 28, 17, 11, 11, 77991))
# (893, 156, datetime.datetime(2022, 2, 28, 17, 11, 11, 78050))
# (270, 416, datetime.datetime(2022, 2, 28, 17, 11, 11, 78739))
# (712, 370, datetime.datetime(2022, 2, 28, 17, 11, 11, 79154))
# (723, 3, datetime.datetime(2022, 2, 28, 17, 11, 11, 79547))
# (811, 12, datetime.datetime(2022, 2, 28, 17, 11, 11, 79948))
# (93, 899, datetime.datetime(2022, 2, 28, 17, 11, 11, 80340))
# (618, 644, datetime.datetime(2022, 2, 28, 17, 11, 11, 80743))
# (609, 672, datetime.datetime(2022, 2, 28, 17, 11, 11, 80803))
# (648, 59, datetime.datetime(2022, 2, 28, 17, 11, 11, 81513))
# (402, 356, datetime.datetime(2022, 2, 28, 17, 11, 11, 81927))
# (209, 853, datetime.datetime(2022, 2, 28, 17, 11, 11, 81990))
# (740, 742, datetime.datetime(2022, 2, 28, 17, 11, 11, 82716))
# (244, 910, datetime.datetime(2022, 2, 28, 17, 11, 11, 82777))
# (192, 105, datetime.datetime(2022, 2, 28, 17, 11, 11, 83168))
# (848, 507, datetime.datetime(2022, 2, 28, 17, 11, 11, 83228))
# (239, 342, datetime.datetime(2022, 2, 28, 17, 11, 11, 84256))
# (309, 210, datetime.datetime(2022, 2, 28, 17, 11, 11, 84672))
# (575, 60, datetime.datetime(2022, 2, 28, 17, 11, 11, 84736))
# (980, 336, datetime.datetime(2022, 2, 28, 17, 11, 11, 85806))
# (703, 131, datetime.datetime(2022, 2, 28, 17, 11, 11, 85879))
# (529, 902, datetime.datetime(2022, 2, 28, 17, 11, 11, 86275))
# (176, 404, datetime.datetime(2022, 2, 28, 17, 11, 11, 86692))
# (863, 689, datetime.datetime(2022, 2, 28, 17, 11, 11, 86752))
# (858, 751, datetime.datetime(2022, 2, 28, 17, 11, 11, 87517))
# (175, 252, datetime.datetime(2022, 2, 28, 17, 11, 11, 87931))
# (869, 783, datetime.datetime(2022, 2, 28, 17, 11, 11, 88347))
# (178, 911, datetime.datetime(2022, 2, 28, 17, 11, 11, 88770))
# (430, 867, datetime.datetime(2022, 2, 28, 17, 11, 11, 89347))
# (480, 149, datetime.datetime(2022, 2, 28, 17, 11, 11, 89570))
# (820, 488, datetime.datetime(2022, 2, 28, 17, 11, 11, 89982))
# (845, 856, datetime.datetime(2022, 2, 28, 17, 11, 11, 90385))
# (882, 911, datetime.datetime(2022, 2, 28, 17, 11, 11, 90801))
# (134, 175, datetime.datetime(2022, 2, 28, 17, 11, 11, 91197))
# (503, 347, datetime.datetime(2022, 2, 28, 17, 11, 11, 91592))
# (811, 809, datetime.datetime(2022, 2, 28, 17, 11, 11, 92002))
# (897, 905, datetime.datetime(2022, 2, 28, 17, 11, 11, 92406))
# (538, 59, datetime.datetime(2022, 2, 28, 17, 11, 11, 92468))
# (71, 685, datetime.datetime(2022, 2, 28, 17, 11, 11, 93209))
# (928, 163, datetime.datetime(2022, 2, 28, 17, 11, 11, 93613))
# (390, 876, datetime.datetime(2022, 2, 28, 17, 11, 11, 94023))
# (369, 495, datetime.datetime(2022, 2, 28, 17, 11, 11, 94759))
# (860, 492, datetime.datetime(2022, 2, 28, 17, 11, 11, 94832))
# (936, 158, datetime.datetime(2022, 2, 28, 17, 11, 11, 94887))
# (638, 227, datetime.datetime(2022, 2, 28, 17, 11, 11, 95600))
# (321, 296, datetime.datetime(2022, 2, 28, 17, 11, 11, 96017))
# (449, 241, datetime.datetime(2022, 2, 28, 17, 11, 11, 96436))
# (329, 101, datetime.datetime(2022, 2, 28, 17, 11, 11, 96846))
# (716, 395, datetime.datetime(2022, 2, 28, 17, 11, 11, 96909))
# (207, 760, datetime.datetime(2022, 2, 28, 17, 11, 11, 97598))
# (399, 609, datetime.datetime(2022, 2, 28, 17, 11, 11, 98001))
# (27, 925, datetime.datetime(2022, 2, 28, 17, 11, 11, 98393))
# (822, 807, datetime.datetime(2022, 2, 28, 17, 11, 11, 98793))
# (176, 880, datetime.datetime(2022, 2, 28, 17, 11, 11, 99178))
# (558, 240, datetime.datetime(2022, 2, 28, 17, 11, 11, 99565))
# (878, 139, datetime.datetime(2022, 2, 28, 17, 11, 11, 99969))
# (721, 123, datetime.datetime(2022, 2, 28, 17, 11, 11, 100365))
# (69, 739, datetime.datetime(2022, 2, 28, 17, 11, 11, 100779))
# (801, 329, datetime.datetime(2022, 2, 28, 17, 11, 11, 101181))
# (384, 358, datetime.datetime(2022, 2, 28, 17, 11, 11, 101992))
# (250, 958, datetime.datetime(2022, 2, 28, 17, 11, 11, 102061))
# (648, 328, datetime.datetime(2022, 2, 28, 17, 11, 11, 102442))
# (249, 228, datetime.datetime(2022, 2, 28, 17, 11, 11, 102860))
# (865, 564, datetime.datetime(2022, 2, 28, 17, 11, 11, 103254))
# (509, 216, datetime.datetime(2022, 2, 28, 17, 11, 11, 103314))
# (72, 711, datetime.datetime(2022, 2, 28, 17, 11, 11, 104037))
# (172, 838, datetime.datetime(2022, 2, 28, 17, 11, 11, 104429))
# (268, 416, datetime.datetime(2022, 2, 28, 17, 11, 11, 104850))
# (889, 760, datetime.datetime(2022, 2, 28, 17, 11, 11, 105251))
# (557, 915, datetime.datetime(2022, 2, 28, 17, 11, 11, 105670))
# (143, 222, datetime.datetime(2022, 2, 28, 17, 11, 11, 105734))
# (741, 492, datetime.datetime(2022, 2, 28, 17, 11, 11, 106438))
# (5, 888, datetime.datetime(2022, 2, 28, 17, 11, 11, 106857))
# (978, 676, datetime.datetime(2022, 2, 28, 17, 11, 11, 107247))
# (493, 381, datetime.datetime(2022, 2, 28, 17, 11, 11, 107640))
# (608, 930, datetime.datetime(2022, 2, 28, 17, 11, 11, 107716))
# (140, 43, datetime.datetime(2022, 2, 28, 17, 11, 11, 108108))
# (164, 221, datetime.datetime(2022, 2, 28, 17, 11, 11, 108506))
# (875, 522, datetime.datetime(2022, 2, 28, 17, 11, 11, 109248))
# (613, 569, datetime.datetime(2022, 2, 28, 17, 11, 11, 109308))
# (306, 785, datetime.datetime(2022, 2, 28, 17, 11, 11, 110015))
# (114, 3, datetime.datetime(2022, 2, 28, 17, 11, 11, 110075))
# (355, 913, datetime.datetime(2022, 2, 28, 17, 11, 11, 110785))
# (351, 627, datetime.datetime(2022, 2, 28, 17, 11, 11, 111190))
# (162, 274, datetime.datetime(2022, 2, 28, 17, 11, 11, 111587))
# (201, 810, datetime.datetime(2022, 2, 28, 17, 11, 11, 111994))
# (881, 233, datetime.datetime(2022, 2, 28, 17, 11, 11, 112378))
# (942, 391, datetime.datetime(2022, 2, 28, 17, 11, 11, 112437))
# (351, 728, datetime.datetime(2022, 2, 28, 17, 11, 11, 113139))
# (970, 565, datetime.datetime(2022, 2, 28, 17, 11, 11, 113522))
# (960, 619, datetime.datetime(2022, 2, 28, 17, 11, 11, 113929))
# (912, 848, datetime.datetime(2022, 2, 28, 17, 11, 11, 114315))
# (732, 138, datetime.datetime(2022, 2, 28, 17, 11, 11, 114373))
# (785, 19, datetime.datetime(2022, 2, 28, 17, 11, 11, 115071))
# (520, 861, datetime.datetime(2022, 2, 28, 17, 11, 11, 115455))
# (451, 805, datetime.datetime(2022, 2, 28, 17, 11, 11, 115879))
# (261, 416, datetime.datetime(2022, 2, 28, 17, 11, 11, 116268))
# (759, 503, datetime.datetime(2022, 2, 28, 17, 11, 11, 116667))
# (299, 961, datetime.datetime(2022, 2, 28, 17, 11, 11, 116728))
# (432, 402, datetime.datetime(2022, 2, 28, 17, 11, 11, 117429))
# (620, 509, datetime.datetime(2022, 2, 28, 17, 11, 11, 117840))
# (508, 554, datetime.datetime(2022, 2, 28, 17, 11, 11, 118377))
# (757, 546, datetime.datetime(2022, 2, 28, 17, 11, 11, 118593))
# (692, 40, datetime.datetime(2022, 2, 28, 17, 11, 11, 118990))
# (763, 205, datetime.datetime(2022, 2, 28, 17, 11, 11, 119048))
# (518, 815, datetime.datetime(2022, 2, 28, 17, 11, 11, 119784))
# (381, 401, datetime.datetime(2022, 2, 28, 17, 11, 11, 120184))
# (715, 323, datetime.datetime(2022, 2, 28, 17, 11, 11, 120243))
# (839, 198, datetime.datetime(2022, 2, 28, 17, 11, 11, 120621))
# (506, 455, datetime.datetime(2022, 2, 28, 17, 11, 11, 121368))
# (857, 717, datetime.datetime(2022, 2, 28, 17, 11, 11, 121785))
# (260, 275, datetime.datetime(2022, 2, 28, 17, 11, 11, 121845))
# (432, 615, datetime.datetime(2022, 2, 28, 17, 11, 11, 122523))
# (14, 633, datetime.datetime(2022, 2, 28, 17, 11, 11, 122582))
# (358, 97, datetime.datetime(2022, 2, 28, 17, 11, 11, 122984))
# (745, 973, datetime.datetime(2022, 2, 28, 17, 11, 11, 123681))
# (953, 109, datetime.datetime(2022, 2, 28, 17, 11, 11, 124050))
# (980, 623, datetime.datetime(2022, 2, 28, 17, 11, 11, 124494))
# (358, 810, datetime.datetime(2022, 2, 28, 17, 11, 11, 124817))
# (915, 563, datetime.datetime(2022, 2, 28, 17, 11, 11, 124853))
# (576, 461, datetime.datetime(2022, 2, 28, 17, 11, 11, 124884))
# (813, 47, datetime.datetime(2022, 2, 28, 17, 11, 11, 124916))
# (108, 265, datetime.datetime(2022, 2, 28, 17, 11, 11, 124946))
# (41, 664, datetime.datetime(2022, 2, 28, 17, 11, 11, 124977))
# (202, 547, datetime.datetime(2022, 2, 28, 17, 11, 11, 125010))
# (302, 613, datetime.datetime(2022, 2, 28, 17, 11, 11, 125069))
# (288, 575, datetime.datetime(2022, 2, 28, 17, 11, 11, 125114))
# (855, 516, datetime.datetime(2022, 2, 28, 17, 11, 11, 125151))
# (335, 795, datetime.datetime(2022, 2, 28, 17, 11, 11, 125197))
# (337, 980, datetime.datetime(2022, 2, 28, 17, 11, 11, 125233))
# (854, 953, datetime.datetime(2022, 2, 28, 17, 11, 11, 125266))
# (484, 430, datetime.datetime(2022, 2, 28, 17, 11, 11, 125296))
# (935, 283, datetime.datetime(2022, 2, 28, 17, 11, 11, 125327))
# (47, 606, datetime.datetime(2022, 2, 28, 17, 11, 11, 125362))
# (587, 247, datetime.datetime(2022, 2, 28, 17, 11, 11, 125399))
# (708, 438, datetime.datetime(2022, 2, 28, 17, 11, 11, 125527))
# (805, 739, datetime.datetime(2022, 2, 28, 17, 11, 11, 125571))
# (479, 185, datetime.datetime(2022, 2, 28, 17, 11, 11, 125605))
# (143, 106, datetime.datetime(2022, 2, 28, 17, 11, 11, 125641))
# (251, 786, datetime.datetime(2022, 2, 28, 17, 11, 11, 125694))
# (239, 255, datetime.datetime(2022, 2, 28, 17, 11, 11, 125729))
# (235, 55, datetime.datetime(2022, 2, 28, 17, 11, 11, 133357))
# (413, 671, datetime.datetime(2022, 2, 28, 17, 11, 11, 133432))
# (799, 962, datetime.datetime(2022, 2, 28, 17, 11, 11, 134766))
# (169, 319, datetime.datetime(2022, 2, 28, 17, 11, 11, 134814))
# (696, 736, datetime.datetime(2022, 2, 28, 17, 11, 11, 134852))
# (320, 775, datetime.datetime(2022, 2, 28, 17, 11, 11, 134886))
# (724, 66, datetime.datetime(2022, 2, 28, 17, 11, 11, 134921))
# (165, 261, datetime.datetime(2022, 2, 28, 17, 11, 11, 134956))
# (796, 163, datetime.datetime(2022, 2, 28, 17, 11, 11, 134991))
# (714, 373, datetime.datetime(2022, 2, 28, 17, 11, 11, 135026))
# (827, 392, datetime.datetime(2022, 2, 28, 17, 11, 11, 135060))
# (852, 512, datetime.datetime(2022, 2, 28, 17, 11, 11, 135094))
# (887, 722, datetime.datetime(2022, 2, 28, 17, 11, 11, 135128))
# (676, 270, datetime.datetime(2022, 2, 28, 17, 11, 11, 135161))
# (726, 642, datetime.datetime(2022, 2, 28, 17, 11, 11, 135193))
# (591, 530, datetime.datetime(2022, 2, 28, 17, 11, 11, 135226))
# (586, 603, datetime.datetime(2022, 2, 28, 17, 11, 11, 135257))
# (342, 668, datetime.datetime(2022, 2, 28, 17, 11, 11, 135290))
# (777, 395, datetime.datetime(2022, 2, 28, 17, 11, 11, 135323))
# (542, 874, datetime.datetime(2022, 2, 28, 17, 11, 11, 135357))
# (766, 836, datetime.datetime(2022, 2, 28, 17, 11, 11, 135391))
# (52, 638, datetime.datetime(2022, 2, 28, 17, 11, 11, 135425))
# (801, 28, datetime.datetime(2022, 2, 28, 17, 11, 11, 135467))
# (95, 293, datetime.datetime(2022, 2, 28, 17, 11, 11, 135502))
# (785, 897, datetime.datetime(2022, 2, 28, 17, 11, 11, 135535))
# (857, 231, datetime.datetime(2022, 2, 28, 17, 11, 11, 135568))
# (612, 299, datetime.datetime(2022, 2, 28, 17, 11, 11, 135601))
# (182, 539, datetime.datetime(2022, 2, 28, 17, 11, 11, 135635))
# (939, 24, datetime.datetime(2022, 2, 28, 17, 11, 11, 135702))
# (150, 12, datetime.datetime(2022, 2, 28, 17, 11, 11, 135741))
# (16, 333, datetime.datetime(2022, 2, 28, 17, 11, 11, 135775))
# (469, 998, datetime.datetime(2022, 2, 28, 17, 11, 11, 135809))
# (37, 719, datetime.datetime(2022, 2, 28, 17, 11, 11, 135846))
# (409, 32, datetime.datetime(2022, 2, 28, 17, 11, 11, 135883))
# (774, 333, datetime.datetime(2022, 2, 28, 17, 11, 11, 135918))
# (447, 164, datetime.datetime(2022, 2, 28, 17, 11, 11, 135952))
# (315, 683, datetime.datetime(2022, 2, 28, 17, 11, 11, 135986))
# (252, 995, datetime.datetime(2022, 2, 28, 17, 11, 11, 136019))
# (73, 856, datetime.datetime(2022, 2, 28, 17, 11, 11, 136052))
# (957, 508, datetime.datetime(2022, 2, 28, 17, 11, 11, 136087))
# (927, 559, datetime.datetime(2022, 2, 28, 17, 11, 11, 136121))
# (630, 205, datetime.datetime(2022, 2, 28, 17, 11, 11, 136158))
# (372, 681, datetime.datetime(2022, 2, 28, 17, 11, 11, 136192))
# (859, 339, datetime.datetime(2022, 2, 28, 17, 11, 11, 136226))
# (121, 734, datetime.datetime(2022, 2, 28, 17, 11, 11, 136260))
# (705, 54, datetime.datetime(2022, 2, 28, 17, 11, 11, 136294))
# (840, 443, datetime.datetime(2022, 2, 28, 17, 11, 11, 136328))
# (384, 181, datetime.datetime(2022, 2, 28, 17, 11, 11, 136361))
# (444, 36, datetime.datetime(2022, 2, 28, 17, 11, 11, 136397))
# (617, 390, datetime.datetime(2022, 2, 28, 17, 11, 11, 136431))
# (248, 417, datetime.datetime(2022, 2, 28, 17, 11, 11, 136463))
# (423, 418, datetime.datetime(2022, 2, 28, 17, 11, 11, 136496))
# (889, 317, datetime.datetime(2022, 2, 28, 17, 11, 11, 136529))
# (318, 566, datetime.datetime(2022, 2, 28, 17, 11, 11, 136564))
# (963, 444, datetime.datetime(2022, 2, 28, 17, 11, 11, 136597))
# (561, 230, datetime.datetime(2022, 2, 28, 17, 11, 11, 136638))
# (787, 378, datetime.datetime(2022, 2, 28, 17, 11, 11, 136695))
# (705, 442, datetime.datetime(2022, 2, 28, 17, 11, 11, 136730))
# (228, 536, datetime.datetime(2022, 2, 28, 17, 11, 11, 136765))
# (908, 240, datetime.datetime(2022, 2, 28, 17, 11, 11, 136799))
# (516, 28, datetime.datetime(2022, 2, 28, 17, 11, 11, 136834))
# (955, 627, datetime.datetime(2022, 2, 28, 17, 11, 11, 136870))
# (598, 146, datetime.datetime(2022, 2, 28, 17, 11, 11, 136904))
# (30, 374, datetime.datetime(2022, 2, 28, 17, 11, 11, 136938))
# (685, 699, datetime.datetime(2022, 2, 28, 17, 11, 11, 136971))
# (66, 733, datetime.datetime(2022, 2, 28, 17, 11, 11, 137003))
# (88, 107, datetime.datetime(2022, 2, 28, 17, 11, 11, 137033))
# (123, 319, datetime.datetime(2022, 2, 28, 17, 11, 11, 137062))
# (519, 708, datetime.datetime(2022, 2, 28, 17, 11, 11, 137092))
# (305, 435, datetime.datetime(2022, 2, 28, 17, 11, 11, 137123))
# (773, 502, datetime.datetime(2022, 2, 28, 17, 11, 11, 137155))
# (522, 39, datetime.datetime(2022, 2, 28, 17, 11, 11, 137185))
# (93, 533, datetime.datetime(2022, 2, 28, 17, 11, 11, 137216))
# (560, 360, datetime.datetime(2022, 2, 28, 17, 11, 11, 137245))
# (51, 952, datetime.datetime(2022, 2, 28, 17, 11, 11, 137275))
# (374, 668, datetime.datetime(2022, 2, 28, 17, 11, 11, 137308))
# (980, 840, datetime.datetime(2022, 2, 28, 17, 11, 11, 137336))
# (857, 879, datetime.datetime(2022, 2, 28, 17, 11, 11, 137365))
# (658, 335, datetime.datetime(2022, 2, 28, 17, 11, 11, 137393))
# (829, 122, datetime.datetime(2022, 2, 28, 17, 11, 11, 137428))
# (929, 225, datetime.datetime(2022, 2, 28, 17, 11, 11, 137460))
# (754, 530, datetime.datetime(2022, 2, 28, 17, 11, 11, 137490))
# (230, 694, datetime.datetime(2022, 2, 28, 17, 11, 11, 137521))
# (272, 808, datetime.datetime(2022, 2, 28, 17, 11, 11, 137552))
# (13, 433, datetime.datetime(2022, 2, 28, 17, 11, 11, 137583))
# (418, 957, datetime.datetime(2022, 2, 28, 17, 11, 11, 137613))
# (689, 575, datetime.datetime(2022, 2, 28, 17, 11, 11, 137647))
# (982, 831, datetime.datetime(2022, 2, 28, 17, 11, 11, 137708))
# (55, 722, datetime.datetime(2022, 2, 28, 17, 11, 11, 137744))
# (466, 763, datetime.datetime(2022, 2, 28, 17, 11, 11, 137785))
# (355, 748, datetime.datetime(2022, 2, 28, 17, 11, 11, 137818))
# (574, 48, datetime.datetime(2022, 2, 28, 17, 11, 11, 137850))
# (379, 708, datetime.datetime(2022, 2, 28, 17, 11, 11, 137881))
# (76, 660, datetime.datetime(2022, 2, 28, 17, 11, 11, 137915))
# (125, 439, datetime.datetime(2022, 2, 28, 17, 11, 11, 137949))
# (538, 490, datetime.datetime(2022, 2, 28, 17, 11, 11, 137984))
# (109, 833, datetime.datetime(2022, 2, 28, 17, 11, 11, 138014))
# (780, 992, datetime.datetime(2022, 2, 28, 17, 11, 11, 138044))
# (869, 85, datetime.datetime(2022, 2, 28, 17, 11, 11, 138072))
# (263, 588, datetime.datetime(2022, 2, 28, 17, 11, 11, 138103))
# (106, 241, datetime.datetime(2022, 2, 28, 17, 11, 11, 138132))
# (510, 713, datetime.datetime(2022, 2, 28, 17, 11, 11, 138164))
# (343, 103, datetime.datetime(2022, 2, 28, 17, 11, 11, 138217))
# (663, 448, datetime.datetime(2022, 2, 28, 17, 11, 11, 138267))
# (111, 231, datetime.datetime(2022, 2, 28, 17, 11, 11, 138306))
# (358, 896, datetime.datetime(2022, 2, 28, 17, 11, 11, 138338))
# (735, 760, datetime.datetime(2022, 2, 28, 17, 11, 11, 138368))
# (877, 751, datetime.datetime(2022, 2, 28, 17, 11, 11, 138397))
# (450, 105, datetime.datetime(2022, 2, 28, 17, 11, 11, 138424))
# (559, 846, datetime.datetime(2022, 2, 28, 17, 11, 11, 138453))
# (226, 495, datetime.datetime(2022, 2, 28, 17, 11, 11, 138486))
# (880, 691, datetime.datetime(2022, 2, 28, 17, 11, 11, 138523))
# (987, 321, datetime.datetime(2022, 2, 28, 17, 11, 11, 138560))
# (787, 410, datetime.datetime(2022, 2, 28, 17, 11, 11, 138595))
# (811, 524, datetime.datetime(2022, 2, 28, 17, 11, 11, 138631))
# (81, 793, datetime.datetime(2022, 2, 28, 17, 11, 11, 138691))
# (386, 505, datetime.datetime(2022, 2, 28, 17, 11, 11, 138730))
# (208, 839, datetime.datetime(2022, 2, 28, 17, 11, 11, 138774))
# (502, 524, datetime.datetime(2022, 2, 28, 17, 11, 11, 138868))
# (768, 742, datetime.datetime(2022, 2, 28, 17, 11, 11, 138907))
# (757, 745, datetime.datetime(2022, 2, 28, 17, 11, 11, 138943))
# (869, 214, datetime.datetime(2022, 2, 28, 17, 11, 11, 138979))
# (731, 568, datetime.datetime(2022, 2, 28, 17, 11, 11, 139014))
# (781, 620, datetime.datetime(2022, 2, 28, 17, 11, 11, 139050))
# (812, 666, datetime.datetime(2022, 2, 28, 17, 11, 11, 139085))
# (996, 175, datetime.datetime(2022, 2, 28, 17, 11, 11, 139137))
# (337, 129, datetime.datetime(2022, 2, 28, 17, 11, 11, 139178))
# (429, 220, datetime.datetime(2022, 2, 28, 17, 11, 11, 139218))
# (471, 620, datetime.datetime(2022, 2, 28, 17, 11, 11, 139254))
# (894, 711, datetime.datetime(2022, 2, 28, 17, 11, 11, 139289))
# (254, 790, datetime.datetime(2022, 2, 28, 17, 11, 11, 139322))
# (65, 56, datetime.datetime(2022, 2, 28, 17, 11, 11, 139375))
# (165, 728, datetime.datetime(2022, 2, 28, 17, 11, 11, 139411))
# (894, 123, datetime.datetime(2022, 2, 28, 17, 11, 11, 139445))
# (535, 73, datetime.datetime(2022, 2, 28, 17, 11, 11, 139479))
# (233, 486, datetime.datetime(2022, 2, 28, 17, 11, 11, 139512))
# (548, 178, datetime.datetime(2022, 2, 28, 17, 11, 11, 139545))
# (529, 514, datetime.datetime(2022, 2, 28, 17, 11, 11, 139579))
# (292, 31, datetime.datetime(2022, 2, 28, 17, 11, 11, 139612))
# (853, 877, datetime.datetime(2022, 2, 28, 17, 11, 11, 139645))
# (174, 414, datetime.datetime(2022, 2, 28, 17, 11, 11, 139715))
# (136, 417, datetime.datetime(2022, 2, 28, 17, 11, 11, 139752))
# (879, 202, datetime.datetime(2022, 2, 28, 17, 11, 11, 139788))
# (114, 467, datetime.datetime(2022, 2, 28, 17, 11, 11, 139826))
# (914, 51, datetime.datetime(2022, 2, 28, 17, 11, 11, 139860))
# (462, 904, datetime.datetime(2022, 2, 28, 17, 11, 11, 139896))
# (897, 567, datetime.datetime(2022, 2, 28, 17, 11, 11, 139931))
# (933, 26, datetime.datetime(2022, 2, 28, 17, 11, 11, 139966))
# (187, 149, datetime.datetime(2022, 2, 28, 17, 11, 11, 140003))
# (968, 803, datetime.datetime(2022, 2, 28, 17, 11, 11, 140039))
# (894, 827, datetime.datetime(2022, 2, 28, 17, 11, 11, 140072))
# (108, 207, datetime.datetime(2022, 2, 28, 17, 11, 11, 140108))
# (33, 382, datetime.datetime(2022, 2, 28, 17, 11, 11, 140142))
# (812, 501, datetime.datetime(2022, 2, 28, 17, 11, 11, 140176))
# (146, 619, datetime.datetime(2022, 2, 28, 17, 11, 11, 140210))
# (940, 820, datetime.datetime(2022, 2, 28, 17, 11, 11, 140243))
# (238, 432, datetime.datetime(2022, 2, 28, 17, 11, 11, 140276))
# (659, 331, datetime.datetime(2022, 2, 28, 17, 11, 11, 140308))
# (148, 947, datetime.datetime(2022, 2, 28, 17, 11, 11, 140346))
# (493, 791, datetime.datetime(2022, 2, 28, 17, 11, 11, 140383))
# (795, 464, datetime.datetime(2022, 2, 28, 17, 11, 11, 140417))
# (543, 865, datetime.datetime(2022, 2, 28, 17, 11, 11, 140451))
# (479, 409, datetime.datetime(2022, 2, 28, 17, 11, 11, 140485))
# (269, 220, datetime.datetime(2022, 2, 28, 17, 11, 11, 140518))
# (364, 625, datetime.datetime(2022, 2, 28, 17, 11, 11, 140550))
# (545, 898, datetime.datetime(2022, 2, 28, 17, 11, 11, 140583))
# (866, 912, datetime.datetime(2022, 2, 28, 17, 11, 11, 140616))
# (419, 984, datetime.datetime(2022, 2, 28, 17, 11, 11, 140650))
# (795, 902, datetime.datetime(2022, 2, 28, 17, 11, 11, 140709))
# (591, 294, datetime.datetime(2022, 2, 28, 17, 11, 11, 140743))
# (580, 864, datetime.datetime(2022, 2, 28, 17, 11, 11, 140777))
# (459, 239, datetime.datetime(2022, 2, 28, 17, 11, 11, 140810))
# (603, 1, datetime.datetime(2022, 2, 28, 17, 11, 11, 140840))
# (896, 54, datetime.datetime(2022, 2, 28, 17, 11, 11, 140874))
# (611, 920, datetime.datetime(2022, 2, 28, 17, 11, 11, 140908))
# (877, 981, datetime.datetime(2022, 2, 28, 17, 11, 11, 140939))
# (606, 77, datetime.datetime(2022, 2, 28, 17, 11, 11, 140972))
# (936, 734, datetime.datetime(2022, 2, 28, 17, 11, 11, 141004))
# (228, 807, datetime.datetime(2022, 2, 28, 17, 11, 11, 141048))
# (822, 310, datetime.datetime(2022, 2, 28, 17, 11, 11, 141089))
# (677, 533, datetime.datetime(2022, 2, 28, 17, 11, 11, 141122))
# (363, 736, datetime.datetime(2022, 2, 28, 17, 11, 11, 141153))
# (37, 23, datetime.datetime(2022, 2, 28, 17, 11, 11, 141186))
# (358, 136, datetime.datetime(2022, 2, 28, 17, 11, 11, 141217))
# (340, 809, datetime.datetime(2022, 2, 28, 17, 11, 11, 141249))
# (500, 46, datetime.datetime(2022, 2, 28, 17, 11, 11, 141283))
# (182, 759, datetime.datetime(2022, 2, 28, 17, 11, 11, 141317))
# (207, 816, datetime.datetime(2022, 2, 28, 17, 11, 11, 141354))
# (144, 582, datetime.datetime(2022, 2, 28, 17, 11, 11, 141388))
# (963, 391, datetime.datetime(2022, 2, 28, 17, 11, 11, 141418))
# (524, 209, datetime.datetime(2022, 2, 28, 17, 11, 11, 141452))
# (355, 727, datetime.datetime(2022, 2, 28, 17, 11, 11, 141482))
# (220, 594, datetime.datetime(2022, 2, 28, 17, 11, 11, 141513))
# (801, 669, datetime.datetime(2022, 2, 28, 17, 11, 11, 141542))
# (736, 839, datetime.datetime(2022, 2, 28, 17, 11, 11, 141573))
# (132, 449, datetime.datetime(2022, 2, 28, 17, 11, 11, 141604))
# (57, 80, datetime.datetime(2022, 2, 28, 17, 11, 11, 141636))
# (145, 932, datetime.datetime(2022, 2, 28, 17, 11, 11, 145845))
# (989, 423, datetime.datetime(2022, 2, 28, 17, 11, 11, 150844))
# (949, 379, datetime.datetime(2022, 2, 28, 17, 11, 11, 153254))
# (742, 471, datetime.datetime(2022, 2, 28, 17, 11, 11, 153309))
# (178, 800, datetime.datetime(2022, 2, 28, 17, 11, 11, 153342))
# (45, 453, datetime.datetime(2022, 2, 28, 17, 11, 11, 153379))
# (165, 130, datetime.datetime(2022, 2, 28, 17, 11, 11, 153414))
# (331, 270, datetime.datetime(2022, 2, 28, 17, 11, 11, 153445))
# (865, 159, datetime.datetime(2022, 2, 28, 17, 11, 11, 153475))
# (175, 670, datetime.datetime(2022, 2, 28, 17, 11, 11, 153507))
# (536, 644, datetime.datetime(2022, 2, 28, 17, 11, 11, 153541))
# (402, 408, datetime.datetime(2022, 2, 28, 17, 11, 11, 153574))
# (499, 589, datetime.datetime(2022, 2, 28, 17, 11, 11, 153604))
# (341, 912, datetime.datetime(2022, 2, 28, 17, 11, 11, 153636))
# (368, 112, datetime.datetime(2022, 2, 28, 17, 11, 11, 153694))
# (788, 971, datetime.datetime(2022, 2, 28, 17, 11, 11, 153729))
# (400, 694, datetime.datetime(2022, 2, 28, 17, 11, 11, 153761))
# (204, 58, datetime.datetime(2022, 2, 28, 17, 11, 11, 153793))
# (537, 603, datetime.datetime(2022, 2, 28, 17, 11, 11, 153828))
# (764, 747, datetime.datetime(2022, 2, 28, 17, 11, 11, 153863))
# (943, 981, datetime.datetime(2022, 2, 28, 17, 11, 11, 153902))
# (336, 373, datetime.datetime(2022, 2, 28, 17, 11, 11, 153937))
# (878, 334, datetime.datetime(2022, 2, 28, 17, 11, 11, 153973))
# (465, 901, datetime.datetime(2022, 2, 28, 17, 11, 11, 154010))
# (39, 265, datetime.datetime(2022, 2, 28, 17, 11, 11, 154049))
# (959, 610, datetime.datetime(2022, 2, 28, 17, 11, 11, 154091))
# (181, 489, datetime.datetime(2022, 2, 28, 17, 11, 11, 154131))
# (966, 441, datetime.datetime(2022, 2, 28, 17, 11, 11, 154186))
# (528, 437, datetime.datetime(2022, 2, 28, 17, 11, 11, 154229))
# (826, 553, datetime.datetime(2022, 2, 28, 17, 11, 11, 154265))
# (173, 915, datetime.datetime(2022, 2, 28, 17, 11, 11, 154296))
# (224, 713, datetime.datetime(2022, 2, 28, 17, 11, 11, 154325))
# (657, 60, datetime.datetime(2022, 2, 28, 17, 11, 11, 154354))
# (41, 717, datetime.datetime(2022, 2, 28, 17, 11, 11, 154383))
# (367, 24, datetime.datetime(2022, 2, 28, 17, 11, 11, 154412))
# (965, 256, datetime.datetime(2022, 2, 28, 17, 11, 11, 154441))
# (202, 93, datetime.datetime(2022, 2, 28, 17, 11, 11, 154470))
# (155, 494, datetime.datetime(2022, 2, 28, 17, 11, 11, 154498))
# (906, 926, datetime.datetime(2022, 2, 28, 17, 11, 11, 154527))
# (460, 387, datetime.datetime(2022, 2, 28, 17, 11, 11, 154555))
# (583, 916, datetime.datetime(2022, 2, 28, 17, 11, 11, 154586))
# (26, 38, datetime.datetime(2022, 2, 28, 17, 11, 11, 154615))
# (333, 539, datetime.datetime(2022, 2, 28, 17, 11, 11, 154645))
# (577, 555, datetime.datetime(2022, 2, 28, 17, 11, 11, 154696))
# (179, 185, datetime.datetime(2022, 2, 28, 17, 11, 11, 154727))
# (407, 33, datetime.datetime(2022, 2, 28, 17, 11, 11, 154758))
# (862, 843, datetime.datetime(2022, 2, 28, 17, 11, 11, 154789))
# (780, 914, datetime.datetime(2022, 2, 28, 17, 11, 11, 154819))
# (351, 551, datetime.datetime(2022, 2, 28, 17, 11, 11, 154856))
# (342, 842, datetime.datetime(2022, 2, 28, 17, 11, 11, 154888))
# (488, 55, datetime.datetime(2022, 2, 28, 17, 11, 11, 154918))
# (847, 623, datetime.datetime(2022, 2, 28, 17, 11, 11, 154946))
# (847, 840, datetime.datetime(2022, 2, 28, 17, 11, 11, 154976))
# (30, 419, datetime.datetime(2022, 2, 28, 17, 11, 11, 155008))
# (146, 811, datetime.datetime(2022, 2, 28, 17, 11, 11, 155044))
# (824, 627, datetime.datetime(2022, 2, 28, 17, 11, 11, 155077))
# (402, 149, datetime.datetime(2022, 2, 28, 17, 11, 11, 155110))
# (272, 659, datetime.datetime(2022, 2, 28, 17, 11, 11, 155143))
# (957, 640, datetime.datetime(2022, 2, 28, 17, 11, 11, 155189))
# (358, 118, datetime.datetime(2022, 2, 28, 17, 11, 11, 155227))
# (232, 504, datetime.datetime(2022, 2, 28, 17, 11, 11, 155264))
# (954, 415, datetime.datetime(2022, 2, 28, 17, 11, 11, 155298))
# (229, 798, datetime.datetime(2022, 2, 28, 17, 11, 11, 155330))
# (168, 621, datetime.datetime(2022, 2, 28, 17, 11, 11, 155359))
# (409, 362, datetime.datetime(2022, 2, 28, 17, 11, 11, 155390))
# (235, 892, datetime.datetime(2022, 2, 28, 17, 11, 11, 155421))
# (169, 766, datetime.datetime(2022, 2, 28, 17, 11, 11, 155452))
# (272, 739, datetime.datetime(2022, 2, 28, 17, 11, 11, 155484))
# (493, 293, datetime.datetime(2022, 2, 28, 17, 11, 11, 155515))
# (518, 618, datetime.datetime(2022, 2, 28, 17, 11, 11, 155546))
# (752, 170, datetime.datetime(2022, 2, 28, 17, 11, 11, 155627))
# (286, 484, datetime.datetime(2022, 2, 28, 17, 11, 11, 155702))
# (360, 949, datetime.datetime(2022, 2, 28, 17, 11, 11, 155760))
# (9, 85, datetime.datetime(2022, 2, 28, 17, 11, 11, 155803))
# (893, 690, datetime.datetime(2022, 2, 28, 17, 11, 11, 155841))
# (310, 602, datetime.datetime(2022, 2, 28, 17, 11, 11, 155886))
# (154, 528, datetime.datetime(2022, 2, 28, 17, 11, 11, 155922))
# (720, 291, datetime.datetime(2022, 2, 28, 17, 11, 11, 155955))
# (103, 652, datetime.datetime(2022, 2, 28, 17, 11, 11, 155987))
# (294, 825, datetime.datetime(2022, 2, 28, 17, 11, 11, 156018))
# (326, 95, datetime.datetime(2022, 2, 28, 17, 11, 11, 156048))
# (290, 300, datetime.datetime(2022, 2, 28, 17, 11, 11, 156077))
# (124, 573, datetime.datetime(2022, 2, 28, 17, 11, 11, 156105))
# (770, 717, datetime.datetime(2022, 2, 28, 17, 11, 11, 156137))
# (359, 839, datetime.datetime(2022, 2, 28, 17, 11, 11, 156187))
# (612, 190, datetime.datetime(2022, 2, 28, 17, 11, 11, 156224))
# (921, 332, datetime.datetime(2022, 2, 28, 17, 11, 11, 156258))
# (533, 969, datetime.datetime(2022, 2, 28, 17, 11, 11, 156297))
# (918, 982, datetime.datetime(2022, 2, 28, 17, 11, 11, 156336))
# (803, 76, datetime.datetime(2022, 2, 28, 17, 11, 11, 156374))
# (856, 465, datetime.datetime(2022, 2, 28, 17, 11, 11, 156411))
# (809, 904, datetime.datetime(2022, 2, 28, 17, 11, 11, 156447))
# (241, 44, datetime.datetime(2022, 2, 28, 17, 11, 11, 156484))
# (435, 274, datetime.datetime(2022, 2, 28, 17, 11, 11, 156518))
# (319, 673, datetime.datetime(2022, 2, 28, 17, 11, 11, 156557))
# (704, 859, datetime.datetime(2022, 2, 28, 17, 11, 11, 156596))
# (874, 625, datetime.datetime(2022, 2, 28, 17, 11, 11, 156634))
# (464, 449, datetime.datetime(2022, 2, 28, 17, 11, 11, 156712))
# (566, 587, datetime.datetime(2022, 2, 28, 17, 11, 11, 156756))
# (600, 231, datetime.datetime(2022, 2, 28, 17, 11, 11, 156792))
# (111, 273, datetime.datetime(2022, 2, 28, 17, 11, 11, 156832))
# (480, 300, datetime.datetime(2022, 2, 28, 17, 11, 11, 156872))
# (408, 576, datetime.datetime(2022, 2, 28, 17, 11, 11, 156909))
# (270, 994, datetime.datetime(2022, 2, 28, 17, 11, 11, 156939))
# (518, 418, datetime.datetime(2022, 2, 28, 17, 11, 11, 156969))
# (348, 545, datetime.datetime(2022, 2, 28, 17, 11, 11, 156997))
# (342, 697, datetime.datetime(2022, 2, 28, 17, 11, 11, 157026))
# (808, 182, datetime.datetime(2022, 2, 28, 17, 11, 11, 157053))
# (519, 190, datetime.datetime(2022, 2, 28, 17, 11, 11, 157082))
# (158, 878, datetime.datetime(2022, 2, 28, 17, 11, 11, 157109))
# (741, 877, datetime.datetime(2022, 2, 28, 17, 11, 11, 157138))
# (265, 234, datetime.datetime(2022, 2, 28, 17, 11, 11, 157176))
# (318, 233, datetime.datetime(2022, 2, 28, 17, 11, 11, 157209))
# (971, 600, datetime.datetime(2022, 2, 28, 17, 11, 11, 157238))
# (721, 453, datetime.datetime(2022, 2, 28, 17, 11, 11, 157269))
# (884, 760, datetime.datetime(2022, 2, 28, 17, 11, 11, 157302))
# (267, 692, datetime.datetime(2022, 2, 28, 17, 11, 11, 157336))
# (785, 294, datetime.datetime(2022, 2, 28, 17, 11, 11, 157479))
# (253, 106, datetime.datetime(2022, 2, 28, 17, 11, 11, 157519))
# (637, 38, datetime.datetime(2022, 2, 28, 17, 11, 11, 157548))
# (39, 322, datetime.datetime(2022, 2, 28, 17, 11, 11, 157577))
# (51, 330, datetime.datetime(2022, 2, 28, 17, 11, 11, 157612))
# (370, 31, datetime.datetime(2022, 2, 28, 17, 11, 11, 157646))
# (291, 740, datetime.datetime(2022, 2, 28, 17, 11, 11, 157701))
# (381, 99, datetime.datetime(2022, 2, 28, 17, 11, 11, 157731))
# (416, 741, datetime.datetime(2022, 2, 28, 17, 11, 11, 157759))
# (111, 462, datetime.datetime(2022, 2, 28, 17, 11, 11, 157790))
# (293, 808, datetime.datetime(2022, 2, 28, 17, 11, 11, 157820))
# (958, 446, datetime.datetime(2022, 2, 28, 17, 11, 11, 157853))
# (400, 520, datetime.datetime(2022, 2, 28, 17, 11, 11, 157889))
# (190, 434, datetime.datetime(2022, 2, 28, 17, 11, 11, 157923))
# (272, 847, datetime.datetime(2022, 2, 28, 17, 11, 11, 157955))
# (465, 187, datetime.datetime(2022, 2, 28, 17, 11, 11, 157987))
# (100, 628, datetime.datetime(2022, 2, 28, 17, 11, 11, 158023))
# (270, 11, datetime.datetime(2022, 2, 28, 17, 11, 11, 158055))
# (714, 616, datetime.datetime(2022, 2, 28, 17, 11, 11, 158102))
# (403, 9, datetime.datetime(2022, 2, 28, 17, 11, 11, 158134))
# (723, 140, datetime.datetime(2022, 2, 28, 17, 11, 11, 158177))
# (748, 493, datetime.datetime(2022, 2, 28, 17, 11, 11, 158213))
# (237, 635, datetime.datetime(2022, 2, 28, 17, 11, 11, 158242))
# (844, 617, datetime.datetime(2022, 2, 28, 17, 11, 11, 158277))
# (211, 620, datetime.datetime(2022, 2, 28, 17, 11, 11, 158309))
# (376, 485, datetime.datetime(2022, 2, 28, 17, 11, 11, 158338))
# (533, 329, datetime.datetime(2022, 2, 28, 17, 11, 11, 158370))
# (136, 638, datetime.datetime(2022, 2, 28, 17, 11, 11, 158400))
# (443, 499, datetime.datetime(2022, 2, 28, 17, 11, 11, 158429))
# (776, 697, datetime.datetime(2022, 2, 28, 17, 11, 11, 158460))
# (980, 593, datetime.datetime(2022, 2, 28, 17, 11, 11, 158488))
# (219, 495, datetime.datetime(2022, 2, 28, 17, 11, 11, 158518))
# (895, 391, datetime.datetime(2022, 2, 28, 17, 11, 11, 158548))
# (719, 410, datetime.datetime(2022, 2, 28, 17, 11, 11, 158581))
# (45, 867, datetime.datetime(2022, 2, 28, 17, 11, 11, 158617))
# (362, 906, datetime.datetime(2022, 2, 28, 17, 11, 11, 164292))
# (683, 117, datetime.datetime(2022, 2, 28, 17, 11, 11, 164367))
# (77, 322, datetime.datetime(2022, 2, 28, 17, 11, 11, 164399))
# (992, 120, datetime.datetime(2022, 2, 28, 17, 11, 11, 164429))
# (483, 814, datetime.datetime(2022, 2, 28, 17, 11, 11, 164461))
# (620, 155, datetime.datetime(2022, 2, 28, 17, 11, 11, 164492))
# (584, 721, datetime.datetime(2022, 2, 28, 17, 11, 11, 164521))
# (931, 953, datetime.datetime(2022, 2, 28, 17, 11, 11, 164589))
# (472, 518, datetime.datetime(2022, 2, 28, 17, 11, 11, 164622))
# (412, 523, datetime.datetime(2022, 2, 28, 17, 11, 11, 164665))
# (403, 750, datetime.datetime(2022, 2, 28, 17, 11, 11, 164703))
# (837, 840, datetime.datetime(2022, 2, 28, 17, 11, 11, 164736))
# (355, 59, datetime.datetime(2022, 2, 28, 17, 11, 11, 164768))
# (46, 878, datetime.datetime(2022, 2, 28, 17, 11, 11, 164800))
# (221, 384, datetime.datetime(2022, 2, 28, 17, 11, 11, 164831))
# (382, 44, datetime.datetime(2022, 2, 28, 17, 11, 11, 164861))
# (539, 696, datetime.datetime(2022, 2, 28, 17, 11, 11, 164890))
# (232, 257, datetime.datetime(2022, 2, 28, 17, 11, 11, 164918))
# (61, 933, datetime.datetime(2022, 2, 28, 17, 11, 11, 164946))
# (165, 870, datetime.datetime(2022, 2, 28, 17, 11, 11, 164974))
# (463, 221, datetime.datetime(2022, 2, 28, 17, 11, 11, 165002))
# (907, 995, datetime.datetime(2022, 2, 28, 17, 11, 11, 165029))
# (744, 987, datetime.datetime(2022, 2, 28, 17, 11, 11, 165056))
# (670, 228, datetime.datetime(2022, 2, 28, 17, 11, 11, 165085))
# (533, 147, datetime.datetime(2022, 2, 28, 17, 11, 11, 165115))
# (41, 417, datetime.datetime(2022, 2, 28, 17, 11, 11, 165146))
# (713, 422, datetime.datetime(2022, 2, 28, 17, 11, 11, 165189))
# (474, 407, datetime.datetime(2022, 2, 28, 17, 11, 11, 165219))
# (385, 262, datetime.datetime(2022, 2, 28, 17, 11, 11, 165248))
# (542, 131, datetime.datetime(2022, 2, 28, 17, 11, 11, 165277))
# (473, 508, datetime.datetime(2022, 2, 28, 17, 11, 11, 165305))
# (762, 792, datetime.datetime(2022, 2, 28, 17, 11, 11, 165333))
# (904, 12, datetime.datetime(2022, 2, 28, 17, 11, 11, 165361))
# (958, 765, datetime.datetime(2022, 2, 28, 17, 11, 11, 165389))
# (916, 974, datetime.datetime(2022, 2, 28, 17, 11, 11, 165417))
# (81, 267, datetime.datetime(2022, 2, 28, 17, 11, 11, 165452))
# (315, 159, datetime.datetime(2022, 2, 28, 17, 11, 11, 165483))
# (824, 435, datetime.datetime(2022, 2, 28, 17, 11, 11, 165516))
# (870, 678, datetime.datetime(2022, 2, 28, 17, 11, 11, 165549))
# (552, 416, datetime.datetime(2022, 2, 28, 17, 11, 11, 165581))
# (156, 755, datetime.datetime(2022, 2, 28, 17, 11, 11, 165617))
# (631, 571, datetime.datetime(2022, 2, 28, 17, 11, 11, 165721))
# (971, 229, datetime.datetime(2022, 2, 28, 17, 11, 11, 165917))
# (249, 983, datetime.datetime(2022, 2, 28, 17, 11, 11, 165953))
# (423, 518, datetime.datetime(2022, 2, 28, 17, 11, 11, 165982))
# (763, 845, datetime.datetime(2022, 2, 28, 17, 11, 11, 166011))
# (972, 694, datetime.datetime(2022, 2, 28, 17, 11, 11, 166038))
# (893, 247, datetime.datetime(2022, 2, 28, 17, 11, 11, 166066))
# (423, 644, datetime.datetime(2022, 2, 28, 17, 11, 11, 166093))
# (899, 572, datetime.datetime(2022, 2, 28, 17, 11, 11, 166122))
# (759, 932, datetime.datetime(2022, 2, 28, 17, 11, 11, 166152))
# (455, 26, datetime.datetime(2022, 2, 28, 17, 11, 11, 166189))
# (855, 834, datetime.datetime(2022, 2, 28, 17, 11, 11, 166218))
# (433, 309, datetime.datetime(2022, 2, 28, 17, 11, 11, 166246))
# (657, 975, datetime.datetime(2022, 2, 28, 17, 11, 11, 166290))
# (252, 780, datetime.datetime(2022, 2, 28, 17, 11, 11, 166344))
# (353, 780, datetime.datetime(2022, 2, 28, 17, 11, 11, 166374))
# (979, 857, datetime.datetime(2022, 2, 28, 17, 11, 11, 166403))
# (162, 882, datetime.datetime(2022, 2, 28, 17, 11, 11, 166432))
# (400, 80, datetime.datetime(2022, 2, 28, 17, 11, 11, 166461))
# (571, 789, datetime.datetime(2022, 2, 28, 17, 11, 11, 166489))
# (525, 233, datetime.datetime(2022, 2, 28, 17, 11, 11, 166517))
# (374, 595, datetime.datetime(2022, 2, 28, 17, 11, 11, 166545))
# (700, 936, datetime.datetime(2022, 2, 28, 17, 11, 11, 166576))
# (577, 460, datetime.datetime(2022, 2, 28, 17, 11, 11, 166605))
# (419, 370, datetime.datetime(2022, 2, 28, 17, 11, 11, 166634))
# (718, 4, datetime.datetime(2022, 2, 28, 17, 11, 11, 166680))
# (878, 585, datetime.datetime(2022, 2, 28, 17, 11, 11, 166712))
# (197, 596, datetime.datetime(2022, 2, 28, 17, 11, 11, 166740))
# (938, 10, datetime.datetime(2022, 2, 28, 17, 11, 11, 166768))
# (376, 542, datetime.datetime(2022, 2, 28, 17, 11, 11, 166796))
# (509, 942, datetime.datetime(2022, 2, 28, 17, 11, 11, 166823))
# (690, 480, datetime.datetime(2022, 2, 28, 17, 11, 11, 166850))
# (729, 498, datetime.datetime(2022, 2, 28, 17, 11, 11, 166880))
# (888, 35, datetime.datetime(2022, 2, 28, 17, 11, 11, 166908))
# (263, 656, datetime.datetime(2022, 2, 28, 17, 11, 11, 166936))
# (744, 880, datetime.datetime(2022, 2, 28, 17, 11, 11, 166965))
# (184, 644, datetime.datetime(2022, 2, 28, 17, 11, 11, 166993))
# (427, 953, datetime.datetime(2022, 2, 28, 17, 11, 11, 167020))
# (860, 603, datetime.datetime(2022, 2, 28, 17, 11, 11, 167048))
# (314, 185, datetime.datetime(2022, 2, 28, 17, 11, 11, 167076))
# (360, 809, datetime.datetime(2022, 2, 28, 17, 11, 11, 167103))
# (274, 455, datetime.datetime(2022, 2, 28, 17, 11, 11, 167134))
# (594, 164, datetime.datetime(2022, 2, 28, 17, 11, 11, 167176))
# (108, 218, datetime.datetime(2022, 2, 28, 17, 11, 11, 167206))
# (778, 322, datetime.datetime(2022, 2, 28, 17, 11, 11, 167233))
# (350, 792, datetime.datetime(2022, 2, 28, 17, 11, 11, 167260))
# (160, 953, datetime.datetime(2022, 2, 28, 17, 11, 11, 167288))
# (700, 929, datetime.datetime(2022, 2, 28, 17, 11, 11, 167316))
# (469, 963, datetime.datetime(2022, 2, 28, 17, 11, 11, 167343))
# (149, 702, datetime.datetime(2022, 2, 28, 17, 11, 11, 167370))
# (422, 612, datetime.datetime(2022, 2, 28, 17, 11, 11, 167399))
# (623, 141, datetime.datetime(2022, 2, 28, 17, 11, 11, 167427))
# (148, 498, datetime.datetime(2022, 2, 28, 17, 11, 11, 167455))
# (9, 20, datetime.datetime(2022, 2, 28, 17, 11, 11, 167484))
# (909, 261, datetime.datetime(2022, 2, 28, 17, 11, 11, 167512))
# (61, 808, datetime.datetime(2022, 2, 28, 17, 11, 11, 167540))
# (311, 546, datetime.datetime(2022, 2, 28, 17, 11, 11, 167568))
# (998, 1, datetime.datetime(2022, 2, 28, 17, 11, 11, 167595))
# (235, 142, datetime.datetime(2022, 2, 28, 17, 11, 11, 167623))
# (799, 617, datetime.datetime(2022, 2, 28, 17, 11, 11, 167677))
# (861, 529, datetime.datetime(2022, 2, 28, 17, 11, 11, 167711))
# (26, 353, datetime.datetime(2022, 2, 28, 17, 11, 11, 167739))
# (420, 610, datetime.datetime(2022, 2, 28, 17, 11, 11, 167767))
# (574, 971, datetime.datetime(2022, 2, 28, 17, 11, 11, 167795))
# (65, 636, datetime.datetime(2022, 2, 28, 17, 11, 11, 167823))
# (919, 104, datetime.datetime(2022, 2, 28, 17, 11, 11, 167851))
# (485, 927, datetime.datetime(2022, 2, 28, 17, 11, 11, 167879))
# (720, 764, datetime.datetime(2022, 2, 28, 17, 11, 11, 167908))
# (913, 412, datetime.datetime(2022, 2, 28, 17, 11, 11, 167937))
# (814, 526, datetime.datetime(2022, 2, 28, 17, 11, 11, 167971))
# (307, 755, datetime.datetime(2022, 2, 28, 17, 11, 11, 167999))
# (190, 277, datetime.datetime(2022, 2, 28, 17, 11, 11, 168027))
# (166, 307, datetime.datetime(2022, 2, 28, 17, 11, 11, 168054))
# (460, 578, datetime.datetime(2022, 2, 28, 17, 11, 11, 168081))
# (557, 665, datetime.datetime(2022, 2, 28, 17, 11, 11, 168179))
# (431, 406, datetime.datetime(2022, 2, 28, 17, 11, 11, 168212))
# (582, 9, datetime.datetime(2022, 2, 28, 17, 11, 11, 168242))
# (947, 925, datetime.datetime(2022, 2, 28, 17, 11, 11, 168270))
# (741, 336, datetime.datetime(2022, 2, 28, 17, 11, 11, 168301))
# (758, 568, datetime.datetime(2022, 2, 28, 17, 11, 11, 168328))
# (160, 789, datetime.datetime(2022, 2, 28, 17, 11, 11, 168356))
# (200, 913, datetime.datetime(2022, 2, 28, 17, 11, 11, 168383))
# (151, 655, datetime.datetime(2022, 2, 28, 17, 11, 11, 168411))
# (506, 15, datetime.datetime(2022, 2, 28, 17, 11, 11, 168438))
# (675, 230, datetime.datetime(2022, 2, 28, 17, 11, 11, 168468))
# (992, 632, datetime.datetime(2022, 2, 28, 17, 11, 11, 168557))
# (909, 994, datetime.datetime(2022, 2, 28, 17, 11, 11, 168610))
# (378, 818, datetime.datetime(2022, 2, 28, 17, 11, 11, 168641))
# (569, 270, datetime.datetime(2022, 2, 28, 17, 11, 11, 168683))
# (743, 234, datetime.datetime(2022, 2, 28, 17, 11, 11, 168712))
# (557, 794, datetime.datetime(2022, 2, 28, 17, 11, 11, 168739))
# (515, 790, datetime.datetime(2022, 2, 28, 17, 11, 11, 168766))
# (633, 187, datetime.datetime(2022, 2, 28, 17, 11, 11, 168793))
# (896, 900, datetime.datetime(2022, 2, 28, 17, 11, 11, 168822))
# (607, 255, datetime.datetime(2022, 2, 28, 17, 11, 11, 168851))
# (21, 694, datetime.datetime(2022, 2, 28, 17, 11, 11, 168879))
# (197, 349, datetime.datetime(2022, 2, 28, 17, 11, 11, 168906))
# (330, 841, datetime.datetime(2022, 2, 28, 17, 11, 11, 168935))
# (672, 984, datetime.datetime(2022, 2, 28, 17, 11, 11, 168963))
# (55, 897, datetime.datetime(2022, 2, 28, 17, 11, 11, 168991))
# (143, 233, datetime.datetime(2022, 2, 28, 17, 11, 11, 169018))
# (671, 110, datetime.datetime(2022, 2, 28, 17, 11, 11, 169044))
# (882, 57, datetime.datetime(2022, 2, 28, 17, 11, 11, 169074))
# (886, 385, datetime.datetime(2022, 2, 28, 17, 11, 11, 169105))
# (422, 886, datetime.datetime(2022, 2, 28, 17, 11, 11, 169135))
# (301, 534, datetime.datetime(2022, 2, 28, 17, 11, 11, 169163))
# (702, 73, datetime.datetime(2022, 2, 28, 17, 11, 11, 169202))
# (384, 92, datetime.datetime(2022, 2, 28, 17, 11, 11, 169231))
# (451, 772, datetime.datetime(2022, 2, 28, 17, 11, 11, 169260))
# (549, 553, datetime.datetime(2022, 2, 28, 17, 11, 11, 169290))
# (312, 27, datetime.datetime(2022, 2, 28, 17, 11, 11, 169319))
# (599, 641, datetime.datetime(2022, 2, 28, 17, 11, 11, 169350))
# (702, 516, datetime.datetime(2022, 2, 28, 17, 11, 11, 169378))
# (668, 706, datetime.datetime(2022, 2, 28, 17, 11, 11, 169405))
# (90, 866, datetime.datetime(2022, 2, 28, 17, 11, 11, 169434))
# (988, 600, datetime.datetime(2022, 2, 28, 17, 11, 11, 169461))
# (315, 875, datetime.datetime(2022, 2, 28, 17, 11, 11, 169488))
# (872, 92, datetime.datetime(2022, 2, 28, 17, 11, 11, 169515))
# (872, 915, datetime.datetime(2022, 2, 28, 17, 11, 11, 169543))
# (663, 120, datetime.datetime(2022, 2, 28, 17, 11, 11, 169570))
# (472, 251, datetime.datetime(2022, 2, 28, 17, 11, 11, 169598))
# (625, 38, datetime.datetime(2022, 2, 28, 17, 11, 11, 169628))
# (864, 14, datetime.datetime(2022, 2, 28, 17, 11, 11, 169670))
# (455, 655, datetime.datetime(2022, 2, 28, 17, 11, 11, 179306))
# (386, 749, datetime.datetime(2022, 2, 28, 17, 11, 11, 180720))
# (854, 268, datetime.datetime(2022, 2, 28, 17, 11, 11, 180781))
# (920, 457, datetime.datetime(2022, 2, 28, 17, 11, 11, 188925))
# (515, 56, datetime.datetime(2022, 2, 28, 17, 11, 11, 191607))
# (823, 589, datetime.datetime(2022, 2, 28, 17, 11, 11, 203758))
# (831, 995, datetime.datetime(2022, 2, 28, 17, 11, 11, 207990))
# (307, 436, datetime.datetime(2022, 2, 28, 17, 11, 11, 211629))
# (290, 337, datetime.datetime(2022, 2, 28, 17, 11, 11, 212898))
# (862, 636, datetime.datetime(2022, 2, 28, 17, 11, 11, 216643))
# (65, 682, datetime.datetime(2022, 2, 28, 17, 11, 11, 220977))
# (194, 618, datetime.datetime(2022, 2, 28, 17, 11, 11, 224762))
# (33, 357, datetime.datetime(2022, 2, 28, 17, 11, 11, 231483))

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
from uuid import NAMESPACE_OID
import sqlite3
from pprint import pprint

conn = sqlite3.connect('social_network.db')
c = conn.cursor()

query = """SELECT people.name, COUNT(relationships.friend_id) FROM relationships
            LEFT JOIN people ON relationships.user_id = people.id
            GROUP BY relationships.user_id
            """

c.execute(query)
results = c.fetchall()
fp = open('report.txt', mode='w')

num = 0
for line in results:
  name = results[num]
  personName = name[0]
  friends = name[1]
  num += 1
  writeline = personName + " has " + str(friends) + " friend(s)!\n"
  fp.write(writeline)



conn.close()

fp.close()

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
